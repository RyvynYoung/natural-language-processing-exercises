# %% [markdown]
# <a id='setup'></a>
# # Setup

# %%
import pandas as pd
df = pd.read_csv('spam.csv', encoding='latin-1', usecols=[0,1])
df.columns = ['label', 'text']
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
labels = pd.concat([df.label.value_counts(),
                    df.label.value_counts(normalize=True)], axis=1)
labels.columns = ['n', 'percent']
labels
# Out:
#          n   percent
# ham   4825  0.865937
# spam   747  0.134063

# %% [markdown]
# ________________________
#
# Clean the text (see [data prep lesson](https://ds.codeup.com/nlp/prepare/#removing-accented-characters)) and create 3 sets of words:
#
# - The words that appear in legitimate text messages.
# - The words that appear in spam text messages.
# - All of the words.

# %%
import unicodedata
import re
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import pandas as pd

def basic_clean(text):
    text = unicodedata.normalize('NFKD', text.lower())\
        .encode('ascii', 'ignore')\
        .decode('utf-8', 'ignore')
    return re.sub(r"[^a-z0-9\s]", '', text)

# %%
df['text_cleaned'] = df.text.apply(basic_clean)
df.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         text_cleaned
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...

# %%
def tokenize(string):
    '''
    This function takes in a string and
    returns a tokenized string.
    '''
    # Create tokenizer.
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # Use tokenizer
    string = tokenizer.tokenize(string, return_str=True)
    
    return string

# %%
df['text_tokenized'] = df.text_cleaned.apply(tokenize)
df.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         text_cleaned  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                       text_tokenized
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...

# %%
def lemmatize(string):
    '''
    This function takes in string for and
    returns a string with words lemmatized.
    '''
    # Create the lemmatizer.
    wnl = nltk.stem.WordNetLemmatizer()
    
    # Use the lemmatizer on each word in the list of words we created by using split.
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    # Join our list of words into a string again and assign to a variable.
    string = ' '.join(lemmas)
    
    return string

# %%
df['text_lemmatized'] = df.text_tokenized.apply(lemmatize)
df.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         text_cleaned  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                       text_tokenized  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                      text_lemmatized
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he go to usf he life around h...

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # Create stopword_list.
    stopword_list = stopwords.words('english')
    
    # Remove 'exclude_words' from stopword_list to keep these in my text.
    stopword_list = set(stopword_list) - set(exclude_words)

    # Add in 'extra_words' to stopword_list.
    stopword_list = stopword_list.union(set(extra_words))
    
    # Split words in string.
    words = string.split()
    
    # Create a list of words from my string with stopwords removed and assign to variable.
    filtered_words = [word for word in words if word not in stopword_list]
    
    # Join words in the list back into strings and assign to a variable.
    string_without_stopwords = ' '.join(filtered_words)
    
    return string_without_stopwords

# %%
df['text_filtered'] = df.text_lemmatized.apply(remove_stopwords)
df.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         text_cleaned  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                       text_tokenized  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                      text_lemmatized  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he go to usf he life around h...
#
#                                        text_filtered
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                u dun say early hor u c already say
# 4           nah dont think go usf life around though

# %%
# add a column with list of words
words = [re.sub(r'([^a-z0-9\s]|\s.\s)', '', doc).split() for doc in df.text_filtered]
words

df = pd.concat([df, pd.DataFrame({'words': words})], axis=1)

# %%
df
# Out:
#      label                                               text  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                            text_cleaned  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will i b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                          text_tokenized  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will i b going to esplanade fr home
# 5569  pity was in mood for that soany other suggestions
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                         text_lemmatized  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he go to usf he life around h...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will i b going to esplanade fr home
# 5569    pity wa in mood for that soany other suggestion
# 5570  the guy did some bitching but i acted like id ...
# 5571                            rofl it true to it name
#
#                                           text_filtered  \
# 0     go jurong point crazy available bugis n great ...
# 1                               ok lar joking wif u oni
# 2     free entry 2 wkly comp win fa cup final tkts 2...
# 3                   u dun say early hor u c already say
# 4              nah dont think go usf life around though
# ...                                                 ...
# 5567  2nd time tried 2 contact u u a750 pound prize ...
# 5568                          b going esplanade fr home
# 5569                      pity wa mood soany suggestion
# 5570  guy bitching acted like id interested buying s...
# 5571                                     rofl true name
#
#                                                   words
# 0     [go, jurong, point, crazy, available, bugisgre...
# 1                             [ok, lar, joking, wifoni]
# 2     [free, entrywkly, comp, win, fa, cup, final, t...
# 3              [u, dun, say, early, horc, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, triedcontactu, a750, pound, prizec...
# 5568                    [b, going, esplanade, fr, home]
# 5569                [pity, wa, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
# [5572 rows x 7 columns]

# %% [markdown]
# **Exploring all the words together, Not by document**
# - any common words that you're missing from the stopword list...noise that is still in that data
# - common words that are spelled different accross the documents
# - are there words more common in spam than ham? vice versa?
#
# **Exploring documents**
# - exploring n-grams

# %%
ham_words = ' '.join(df[df.label == 'ham'].text_filtered)
spam_words = ' '.join(df[df.label == 'spam'].text_filtered)
all_words = ' '.join(df.text_filtered)
ham_words = re.sub(r'\s.\s', '', ham_words)
spam_words = re.sub(r'\s.\s', '', spam_words)
all_words = re.sub(r'\s.\s', '', all_words)

# %%
spam_words
# Out:
# 'free entrywkly comp win fa cup final tkts 21st may 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s freemsg hey darlingweek word back id like fun still tb ok xxx std chgs send a150 rcv winner valued network customer selected receivea a900 prize reward claim call 09061701461 claim code kl341 valid 12 hour mobile 11 monthr entitled update latest colour mobile camera free call mobile update co free 08002986030 six chance win cash 100 20000 pound txt csh11 send 87575 cost 150pday 6days 16 tsandcs apply reply hlinfo urgentweek free membership a100000 prize jackpot txt word claim 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18 xxxmobilemovieclub use credit click wap link next txt message click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl englandmacedonia dont miss goalsteam news txt ur national team 87077 eg england 87077 trywales scotland 4txti14120 poboxox36504w45wq 16 thanks subscription ringtone uk mobile charged a5month please confirm replying yes reply charged 07732584351 rodger burn msg tried call reply sm free nokia mobile free camcorder please call 08000930705 delivery tomorrow sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end reply end sptv congratsyear special cinema pascall 09061209465suprmanmatrix3 starwars3 etcfree bx420ip45we 150pm dont miss valued customer pleased advise following recent review mob awarded a1500 bonus prize call 09066364589 urgent ur awarded complimentary trip eurodisinc trav acoentry41 a1000 claim txt dis 87121 186a150morefrmmob shracomorsglsuplt10 ls1 3aj hear new divorce barbie come ken stuff please call customer service representative 0800 169 6031 10am9pm guaranteed a1000 cash a5000 prize free ringtone waiting collected simply text password mix 85069 verify get usher britney fml gent trying contact last weekend draw show a1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm winnerspecially selectedreceive a1000holiday flight inc speak live operatorclaim 0871277810910pmin 18 private 2004 account statement 07742676969 show 786 unredeemed bonus point claim call 08719180248 identifier code 45239 expires urgent mobile wa awarded a2000 bonus caller prize 5903 final try contactcall landline 09064019788 box42wr29c 150ppm today voda number ending 7548 selected receive 350 award match please call 08712300220 quoting claim code 4041 standard rate app sunshine quiz wklywin top sony dvd playerknow country algarve txt ansr 82277 a150 sptyrone wantget laid tonight want real dogging location sent directur mob join uk largest dogging network bt txting gravel 69888 nt ec2a 31pmsg150p youll rcv msg chat svc free hardcore service text go 69988get nothingmust age verify yr network try freemsg havent replied text im randy sexy female live local luv hearnetcollex ltd 08700621170150p per msg reply stop end customer service annoncement new year delivery waiting please call 07046744435 arrange delivery winnerspecially selectedreceive a1000 cashholiday flight inc speak live operatorclaim 0871277810810 pls stop bootydelious 32f inviting friend reply yes434 no434 see wwwsmsacubootydelious stop send stop frnd 62468 bangbabes ur order wayreceive service msgdownload ur contentgoto wap bangb tv ur mobile internetservice menu urgent trying contact last weekend draw show a900 prize guaranteed call 09061701939 claim code s89 valid 12hrs please call customer service representative freephone 0808 145 4742 9am11pm guaranteed a1000 cash a5000 prize unique enough find 30th august wwwareyouuniquecouk 500 new mobile 2004 must go txt nokia 89545 collect todayfrom a1 www4tcbiz 2optout 08718726270150gbpmtmsg18meet ur dream partner soon ur careerflyng startfind free txt horo followed ur star signg horo aries text meet someone sexy todayfind date even flirtjoin10p reply name age eg sam 25 18 msg recdthirtyeight penny447801259231 secret admirer lookingmake contact ufind rreveal think ur specialcall 09058094597 congratulation ur awarded 500 cd voucher 125gift ...

# %% [markdown]
# Once we have a list of words, we can transform it into a pandas `Series`, which we can then use to show us how often each of the words occurs.

# %%
ham_freq = pd.Series(ham_words.split()).value_counts()
spam_freq = pd.Series(spam_words.split()).value_counts()
all_freq = pd.Series(all_words.split()).value_counts()

# %%
spam_freq.head()
# Out:
# call    342
# free    191
# txt     140
# text    129
# ur      125
# dtype: int64

# %% [markdown]
# Now we'll combine these three together to get one resulting data frame that we can work with:

# %%
word_counts = (pd.concat([all_freq, ham_freq, spam_freq], axis=1, sort=True)
               .set_axis(['all', 'ham', 'spam'], axis=1, inplace=False)
              .fillna(0)
              .apply(lambda s: s.astype(int))
              )
word_counts.head()
# Out:
#               all  ham  spam
# 008704050406    2    0     2
# 0089my          1    0     1
# 0121            1    0     1
# 01223585236     1    0     1
# 01223585334     2    0     2

# %% [markdown]
# We can now use this data set to answer some interesting questions:
#
# - Are there words that should be added to the stopword list?
# - Are there words that are significantly more likely to occur in spam than in ham?

# %%
word_counts.sort_values(by='all', ascending=False).head(10)
# Out:
#       all  ham  spam
# call  551  209   342
# im    450  436    13
# get   351  278    73
# ur    343  220   125
# dont  257  237    19
# ok    250  245     5
# ltgt  248  248     0
# go    246  218    27
# free  240   49   191
# know  227  214    13

# %%
word_counts[word_counts.spam==0].sort_values(by='ham').tail(5)
# Out:
#        all  ham  spam
# say    107  107     0
# later  119  118     0
# da     121  121     0
# lor    129  129     0
# ltgt   248  248     0

# %%
word_counts[word_counts.ham<5].sort_values(by='spam').tail(10)
# Out:
#             all  ham  spam
# awarded      38    0    38
# 18           41    0    41
# 16           45    1    46
# tc           51    2    49
# guaranteed   50    0    50
# urgent       60    2    59
# tone         60    0    60
# nokia        63    1    62
# prize        82    0    82
# claim        96    0    96

# %% [markdown]
# ### Document Word Count
#
# The length of documents is often a good feature.

# %%
df['doc_length'] = [len(wordlist) for wordlist in df.words]

# %%
df.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         text_cleaned  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                       text_tokenized  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...
#
#                                      text_lemmatized  \
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he go to usf he life around h...
#
#                                        text_filtered  \
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                u dun say early hor u c already say
# 4           nah dont think go usf life around though
#
#                                                words  doc_length
# 0  [go, jurong, point, crazy, available, bugisgre...          12
# 1                          [ok, lar, joking, wifoni]           4
# 2  [free, entrywkly, comp, win, fa, cup, final, t...          21
# 3           [u, dun, say, early, horc, already, say]           7
# 4  [nah, dont, think, go, usf, life, around, though]           8

# %%
df = df[df.doc_length != 0]

# %% [markdown]
# ## Visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# visualize the % of the term in ham vs. spam
# figure out the percentage of spam vs ham
(word_counts
 .assign(p_spam=word_counts.spam / word_counts['all'],
         p_ham=word_counts.ham / word_counts['all'])
 .sort_values(by='all')
 [['p_spam', 'p_ham']]
 .tail(20)
 .sort_values('p_ham')
 .plot.barh(stacked=True))

plt.title('Proportion of Spam vs Ham for the 20 most common words')
# Out:
# Text(0.5, 1.0, 'Proportion of Spam vs Ham for the 20 most common words')

# %% [markdown]
# ### Word Clouds
#
# ```
# python -m pip install --upgrade wordcloud
# ```
#
# The wordcloud allows you to identify the relative frequency of different keywords using an easily digestible visual.
#
# #### Common Use Cases
#
# As a visualization technique, this method gives a more qualitative analysis of the topics in the documents.
#
# #### Pros
#
# 1. It’s intuitive and easy to comprehend.
# 2. It helps identify overall respondent sentiment and the specific factors that drive it.
# 3. It provides direction for further analysis.
#
# #### Cons
#
# 1. It fails to measure each word’s value in and of itself.
# 2. It allows irrelevant words to appear.
# 3. When words appear similar in size, it becomes difficult to differentiate them.
#
# First we'll take a look at a simple example:

# %%
from wordcloud import WordCloud

sentence = 'Mary had a little lamb, little lamb, little lamb. Its fleece was white as snow.'

img = WordCloud(background_color='white').generate(sentence)
# WordCloud() produces an image object, which can be displayed with plt.imshow
plt.imshow(img)
# axis aren't very useful for a word cloud
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
ham_words
# Out:
# 'go jurong point crazy available bugisgreat world labuffet cine got amore wat ok lar joking wifonidun say early horc already say nah dont think go usf life around though even brother like speak treat like aid patent per request melle melle oru minnaminunginte nurungu vettam ha set callertune caller presscopy friend callertune im gonna home soon dont want talk stuff anymore tonightive cried enough today ive searching right word thank breather promise wont take help granted fulfil promise wonderful blessing time date sunday oh kim watching ehrememberspell name yesnaughty makewet fine thataos wayfeel thataos way gotaseriously spell name ium going trymonth ha ha joking pay first lar da stock comin aft finish lunch go str lor ardsmth lorfinish ur lunch already ffffffffff alright way meet sooner forced eat slice im really hungry tho suck mark getting worried know im sick turn pizza lol lol always convincing catch bus frying egg make tea eating mom left dinner feel love im back amp packing car ill let know room ahhh work vaguely remember doe feel like lol wait thats still clear sure sarcastic thatsdoesnt want liveyeah gotwaapologeticfallen wa actin like spoilt child got caught tillwont go badly cheertell anything fear fainting housework quick cuppa yup ok go home look timing msg xuhui going learn 2nd may lesson 8am oops ill let know roommate done see lettercar anything lordecide hello hows saturday go wa texting see youd decided anything tomo im trying invite anything pls go ahead watt wanted sure great weekend abiola forget tell want need crave love sweet arabian steed mmmmmm yummy seeing great hope like man well endowed ltgt inch callsmessagesmissed call didnt get hepimmunisation nigeria fair enough anything going yeah hopefully tyler cant could maybe ask around bitdont know stubborn didnt even want go hospital kept telling mark im weak sucker hospital weak sucker thinked first time saw class gram usually run like ltgt half eighth smarter though get almost whole second gram ltgtfyiha ride early tomorrow morning crashing place tonight wow never realized embarassed accomodations thought liked since wa best could always seemed happy cave im sorry didnt dont give im sorry offered im sorry room wa embarassing know mallika sherawat yesterday find lturlgt sorry ill call later meeting tell reached yesgauti sehwag odi series gonna pickburger way home cant even move pain killing ha ha ha good joke girl situation seeker part checking iq sorry roommate took forever ok come ok lar double check wif da hair dresser already said wun cutshort said cut look nice today song dedicated day songdedicate send ur valuable frnds first rply plane give month end wah lucky man save money hee finished class hi babe im home wanna something xx kkwhere youhow performedcall waiting machan call free thats cool gentleman treat dignity respect like people much shy pa doe operate ltgt still looking job much ta earn sorry ill call latercall ah ok way home hi hi place man yup next stop call later dont network urgnt sm realgetting yo needticket one jacket im done already used multis yes started send request make pain came back im back bed double coin factory gotta cash nitros im really still tonight babe ela kanoil download come wen ur free yeah donut stand close tho youull catch something sorry pain ok meet another night spent late afternoon casualty mean havent done stuff42moro includes time sheet sorry smile pleasure smile pain smile trouble pours like rain smile sum1 hurtsmile becoz someone still love seesmiling havent planning buy later check already lido got 530 showafternoonfinish work already watching telugu moviewat abtsee finish load loan pay hi wk ok hols yes bit run forgot hairdresser appointment four need get homeshower beforehand doe cause probham please dont text anymore nothing else say okay name ur price long legal wen pickavexx im still looking car buy gone 4the driving test yet per request melle melle oru minnaminunginte nurungu vettam ha set callertun ...

# %%
all_cloud = WordCloud(background_color='white', height=1000, width=400).generate(all_words)
ham_cloud = WordCloud(background_color='pink', height=600, width=800).generate(ham_words)
spam_cloud = WordCloud(background_color='blue', height=600, width=800).generate(spam_words)

plt.figure(figsize=(10, 8))
axs = [plt.axes([0, 0, .5, 1]), plt.axes([.5, .5, .5, .5]), plt.axes([.5, 0, .5, .5])]

axs[0].imshow(all_cloud)
axs[1].imshow(ham_cloud)
axs[2].imshow(spam_cloud)

axs[0].set_title('All Words')
axs[1].set_title('Ham')
axs[2].set_title('Spam')

for ax in axs: ax.axis('off')

# %% [markdown]
# <a id='Bi-Grams'></a>
# # Bi-Grams

# %% [markdown]
# ## Bigrams
#
# Bigrams are a specific instance of the broader concept of n-grams, which is a way to combine words together. This lets us measure not just the individual word frequency, but also takes into account which words appear together.
#
# To produce the bigrams, we'll use `nltk`.

# %%
sentence = 'Mary had a little lamb'

bigrams = nltk.ngrams(sentence.split(), 2)
list(bigrams)
# Out:
# [('Mary', 'had'), ('had', 'a'), ('a', 'little'), ('little', 'lamb')]

# %%
[list(nltk.ngrams(wordlist, 2)) for wordlist in df.words]
# Out:
# [[('go', 'jurong'),
#   ('jurong', 'point'),
#   ('point', 'crazy'),
#   ('crazy', 'available'),
#   ('available', 'bugisgreat'),
#   ('bugisgreat', 'world'),
#   ('world', 'labuffet'),
#   ('labuffet', 'cine'),
#   ('cine', 'got'),
#   ('got', 'amore'),
#   ('amore', 'wat')],
#  [('ok', 'lar'), ('lar', 'joking'), ('joking', 'wifoni')],
#  [('free', 'entrywkly'),
#   ('entrywkly', 'comp'),
#   ('comp', 'win'),
#   ('win', 'fa'),
#   ('fa', 'cup'),
#   ('cup', 'final'),
#   ('final', 'tkts'),
#   ('tkts', '21st'),
#   ('21st', 'may'),
#   ('may', '2005'),
#   ('2005', 'text'),
#   ('text', 'fa'),
#   ('fa', '87121'),
#   ('87121', 'receive'),
#   ('receive', 'entry'),
#   ('entry', 'questionstd'),
#   ('questionstd', 'txt'),
#   ('txt', 'ratetcs'),
#   ('ratetcs', 'apply'),
#   ('apply', '08452810075over18s')],
#  [('u', 'dun'),
#   ('dun', 'say'),
#   ('say', 'early'),
#   ('early', 'horc'),
#   ('horc', 'already'),
#   ('already', 'say')],
#  [('nah', 'dont'),
#   ('dont', 'think'),
#   ('think', 'go'),
#   ('go', 'usf'),
#   ('usf', 'life'),
#   ('life', 'around'),
#   ('around', 'though')],
#  [('freemsg', 'hey'),
#   ('hey', 'darlingweek'),
#   ('darlingweek', 'word'),
#   ('word', 'back'),
#   ('back', 'id'),
#   ('id', 'like'),
#   ('like', 'fun'),
#   ('fun', 'still'),
#   ('still', 'tb'),
#   ('tb', 'ok'),
#   ('ok', 'xxx'),
#   ('xxx', 'std'),
#   ('std', 'chgs'),
#   ('chgs', 'send'),
#   ('send', 'a150'),
#   ('a150', 'rcv')],
#  [('even', 'brother'),
#   ('brother', 'like'),
#   ('like', 'speak'),
#   ('speak', 'treat'),
#   ('treat', 'like'),
#   ('like', 'aid'),
#   ('aid', 'patent')],
#  [('per', 'request'),
#   ('request', 'melle'),
#   ('melle', 'melle'),
#   ('melle', 'oru'),
#   ('oru', 'minnaminunginte'),
#   ('minnaminunginte', 'nurungu'),
#   ('nurungu', 'vettam'),
#   ('vettam', 'ha'),
#   ('ha', 'set'),
#   ('set', 'callertune'),
#   ('callertune', 'caller'),
#   ('caller', 'presscopy'),
#   ('presscopy', 'friend'),
#   ('friend', 'callertune')],
#  [('winner', 'valued'),
#   ('valued', 'network'),
#   ('network', 'customer'),
#   ('customer', 'selected'),
#   ('selected', 'receivea'),
#   ('receivea', 'a900'),
#   ('a900', 'prize'),
#   ('prize', 'reward'),
#   ('reward', 'claim'),
#   ('claim', 'call'),
#   ('call', '09061701461'),
#   ('09061701461', 'claim'),
#   ('claim', 'code'),
#   ('code', 'kl341'),
#   ('kl341', 'valid'),
#   ('valid', '12'),
#   ('12', 'hour')],
#  [('mobile', '11'),
#   ('11', 'monthr'),
#   ('monthr', 'entitled'),
#   ('entitled', 'update'),
#   ('update', 'latest'),
#   ('latest', 'colour'),
#   ('colour', 'mobile'),
#   ('mobile', 'camera'),
#   ('camera', 'free'),
#   ('free', 'call'),
#   ('call', 'mobile'),
#   ('mobile', 'update'),
#   ('update', 'co'),
#   ('co', 'free'),
#   ('free', '08002986030')],
#  [('im', 'gonna'),
#   ('gonna', 'home'),
#   ('home', 'soon'),
#   ('soon', 'dont'),
#   ('dont', 'want'),
#   ('want', 'talk'),
#   ('talk', 'stuff'),
#   ('stuff', 'anymore'),
#   ('anymore', 'tonightive'),
#   ('tonightive', 'cried'),
#   ('cried', 'enough'),
#   ('enough', 'today')],
#  [('six', 'chance'),
#   ('chance', 'win'),
#   ('win', 'cash'),
#   ('cash', '100'),
#   ('100', '20000'),
#   ('20000', 'pound'),
#   ('pound', 'txt'),
#   ('txt', 'csh11'),
#   ('csh11', 'send'),
#   ('send', '87575'),
#   ('87575', 'cost'),
#   ('cost', '150pday'),
#   ('150pday', '6days'),
#   ('6days', '16'),
#   ('16', 'tsandcs'),
#   ('tsandcs', 'apply'),
#   ('apply', 'reply'),
#   ('reply', 'hlinfo')],
#  [('urgentweek', 'free'),
#   ('free', 'membership'),
#   ('membership', 'a100000'),
#   ('a100000', 'prize'),
#   ('prize', 'jackpot'),
#   ('jackpot', 'txt'),
#   ('txt', 'word'),
#   ('word', 'claim'),
#   ('claim', '81010'),
#   ('81010', 'tc'),
#   ('tc', 'wwwdbuknet'),
#   ('wwwdbuknet', 'lccltd'),
#   ('lccltd', 'pobox'),
#   ('pobox', '4403ldnw1a7rw18')],
#  [('ive', 'searching'),
#   ('searching', 'right'),
#   ('right', 'word'),
#   ('word', 'thank'),
#   ('thank', 'breather'),
#   ('breather', 'promise'),
#   ('promise', 'wont'),
#   ('wont', 'take'),
#   ('take', 'help'),
#   ('help', 'granted'),
#   ('granted', 'fulfil'),
#   ('fulfil', 'promise'),
#   ('promise', 'wonderful'),
#   ('wonderful', 'blessing'),
#   ('blessing', 'time')],
#  [('date', 'sunday')],
#  [('xxxmobilemovieclub', 'use'),
#   ('use', 'credit'),
#   ('credit', 'click'),
#   ('click', 'wap'),
#   ('wap', 'link'),
#   ('link', 'next'),
#   ('next', 'txt'),
#   ('txt', 'message'),
#   ('message', 'click'),
#   ('click', 'httpwap'),
#   ('httpwap', 'xxxmobilemovieclubcomnqjkgighjjgcbl')],
#  [('oh', 'kim'), ('kim', 'watching')],
#  [('ehrememberspell', 'name'),
#   ('name', 'yesnaughty'),
#   ('yesnaughty', 'makewet')],
#  [('fine', 'thataos'),
#   ('thataos', 'wayfeel'),
#   ('wayfeel', 'thataos'),
#   ('thataos', 'way'),
#   ('way', 'gota'),
#   ('gota', 'b')],
#  [('englandmacedonia', 'dont'),
#   ('dont', 'miss'),
#   ('miss', 'goalsteam'),
#   ('goalsteam', 'news'),
#   ('news', 'txt'),
#   ('txt', 'ur'),
#   ('ur', 'national'),
#   ('national', 'team'),
#   ('team', '87077'),
#   ('87077', 'eg'),
#   ('eg', 'england'),
#   ('england', '87077'),
#   ('87077', 'trywales'),
#   ('trywales', 'scotland'),
#   ('scotland', '4txti14120'),
#   ('4txti14120', 'poboxox36504w45wq'),
#   ('poboxox36504w45wq', '16')],
#  [('seriously', 'spell'), ('spell', 'name')],
#  [('ium', 'going'),
#   ('going', 'trymonth'),
#   ('trymonth', 'ha'),
#   ('ha', 'ha'),
#   ('ha', 'joking')],
#  [('pay', 'first'),
#   ('first', 'lar'),
#   ('lar', 'da'),
#   ('da', 'stock'),
#   ('stock', 'comin')],
#  [('aft', 'finish'),
#   ('finish', 'lunch'),
#   ('lunch', 'go'),
#   ('go', 'str'),
#   ('str', 'lor'),
#   ('lor', 'ardsmth'),
#   ('ardsmth', 'lorfinish'),
#   ('lorfinish', 'ur'),
#   ('ur', 'lunch'),
#   ('lunch', 'already')],
#  [('ffffffffff', 'alright'),
#   ('alright', 'way'),
#   ('way', 'meet'),
#   ('meet', 'sooner')],
#  [('forced', 'eat'),
#   ('eat', 'slice'),
#   ('slice', 'im'),
#   ('im', 'really'),
#   ('really', 'hungry'),
#   ('hungry', 'tho'),
#   ('tho', 'suck'),
#   ('suck', 'mark'),
#   ('mark', 'getting'),
#   ('getting', 'worried'),
#   ('worried', 'know'),
#   ('know', 'im'),
#   ('im', 'sick'),
#   ('sick', 'turn'),
#   ('turn', 'pizza'),
#   ('pizza', 'lol')],
#  [('lol', 'always'), ('always', 'convincing')],
#  [('catch', 'bus'),
#   ('bus', 'frying'),
#   ('frying', 'egg'),
#   ('egg', 'make'),
#   ('make', 'tea'),
#   ('tea', 'eating'),
#   ('eating', 'mom'),
#   ('mom', 'left'),
#   ('left', 'dinner'),
#   ('dinner', 'feel'),
#   ('feel', 'love')],
#  [('im', 'back'),
#   ('back', 'amp'),
#   ('amp', 'packing'),
#   ('packing', 'car'),
#   ('car', 'ill'),
#   ('ill', 'let'),
#   ('let', 'know'),
#   ('know', 'room')],
#  [('ahhh', 'work'),
#   ('work', 'vaguely'),
#   ('vaguely', 'remember'),
#   ('remember', 'doe'),
#   ('doe', 'feel'),
#   ('feel', 'like'),
#   ('like', 'lol')],
#  [('wait', 'thats'),
#   ('thats', 'still'),
#   ('still', 'clear'),
#   ('clear', 'sure'),
#   ('sure', 'sarcastic'),
#   ('sarcastic', 'thatsdoesnt'),
#   ('thatsdoesnt', 'want'),
#   ('want', 'live'),
#   ('live', 'u')],
#  [('yeah', 'gotwaapologeticfallen'),
#   ('gotwaapologeticfallen', 'wa'),
#   ('wa', 'actin'),
#   ('actin', 'like'),
#   ('like', 'spoilt'),
#   ('spoilt', 'child'),
#   ('child', 'got'),
#   ('got', 'caught'),
#   ('caught', 'tillwont'),
#   ('tillwont', 'go'),
#   ('go', 'badly'),
#   ('badly', 'cheer')],
#  [('k', 'tell'), ('tell', 'anything')],
#  [('fear', 'fainting'),
#   ('fainting', 'housework'),
#   ('housework', 'quick'),
#   ('quick', 'cuppa')],
#  [('thanks', 'subscription'),
#   ('subscription', 'ringtone'),
#   ('ringtone', 'uk'),
#   ('uk', 'mobile'),
#   ('mobile', 'charged'),
#   ('charged', 'a5month'),
#   ('a5month', 'please'),
#   ('please', 'confirm'),
#   ('confirm', 'replying'),
#   ('replying', 'yes'),
#   ('yes', 'reply'),
#   ('reply', 'charged')],
#  [('yup', 'ok'),
#   ('ok', 'go'),
#   ('go', 'home'),
#   ('home', 'look'),
#   ('look', 'timing'),
#   ('timing', 'msg'),
#   ('msg', 'xuhui'),
#   ('xuhui', 'going'),
#   ('going', 'learn'),
#   ('learn', '2nd'),
#   ('2nd', 'may'),
#   ('may', 'lesson'),
#   ('lesson', '8am')],
#  [('oops', 'ill'),
#   ('ill', 'let'),
#   ('let', 'know'),
#   ('know', 'roommate'),
#   ('roommate', 'done')],
#  [('see', 'lettercar')],
#  [('anything', 'lordecide')],
#  [('hello', 'hows'),
#   ('hows', 'saturday'),
#   ('saturday', 'go'),
#   ('go', 'wa'),
#   ('wa', 'texting'),
#   ('texting', 'see'),
#   ('see', 'youd'),
#   ('youd', 'decided'),
#   ('decided', 'anything'),
#   ('anything', 'tomo'),
#   ('tomo', 'im'),
#   ('im', 'trying'),
#   ('trying', 'invite'),
#   ('invite', 'anything')],
#  [('pls', 'go'),
#   ('go', 'ahead'),
#   ('ahead', 'watt'),
#   ('watt', 'wanted'),
#   ('wanted', 'sure'),
#   ('sure', 'great'),
#   ('great', 'weekend'),
#   ('weekend', 'abiola')],
#  [('forget', 'tell'),
#   ('tell', 'want'),
#   ('want', 'need'),
#   ('need', 'crave'),
#   ('crave', 'love'),
#   ('love', 'sweet'),
#   ('sweet', 'arabian'),
#   ('arabian', 'steed'),
#   ('steed', 'mmmmmm'),
#   ('mmmmmm', 'yummy')],
#  [('07732584351', 'rodger'),
#   ('rodger', 'burn'),
#   ('burn', 'msg'),
#   ('msg', 'tried'),
#   ('tried', 'call'),
#   ('call', 'reply'),
#   ('reply', 'sm'),
#   ('sm', 'free'),
#   ('free', 'nokia'),
#   ('nokia', 'mobile'),
#   ('mobile', 'free'),
#   ('free', 'camcorder'),
#   ('camcorder', 'please'),
#   ('please', 'call'),
#   ('call', '08000930705'),
#   ('08000930705', 'delivery'),
#   ('delivery', 'tomorrow')],
#  [],
#  [('great', 'hope'),
#   ('hope', 'like'),
#   ('like', 'man'),
#   ('man', 'well'),
#   ('well', 'endowed'),
#   ('endowed', 'ltgt'),
#   ('ltgt', 'inch')],
#  [('callsmessagesmissed', 'call')],
#  [('didnt', 'get'),
#   ('get', 'hepimmunisation'),
#   ('hepimmunisation', 'nigeria')],
#  [('fair', 'enough'), ('enough', 'anything'), ('anything', 'going')],
#  [('yeah', 'hopefully'),
#   ('hopefully', 'tyler'),
#   ('tyler', 'cant'),
#   ('cant', 'could'),
#   ('could', 'maybe'),
#   ('maybe', 'ask'),
#   ('ask', 'around'),
#   ('around', 'bit')],
#  [('u', 'dont'),
#   ('dont', 'know'),
#   ('know', 'stubborn'),
#   ('stubborn', 'didnt'),
#   ('didnt', 'even'),
#   ('even', 'want'),
#   ('want', 'go'),
#   ('go', 'hospital'),
#   ('hospital', 'kept'),
#   ('kept', 'telling'),
#   ('telling', 'mark'),
#   ('mark', 'im'),
#   ('im', 'weak'),
#   ('weak', 'sucker'),
#   ('sucker', 'hospital'),
#   ('hospital', 'weak'),
#   ('weak', 'sucker')],
#  [('thinked', 'first'), ('first', 'time'), ('time', 'saw'), ('saw', 'class')],
#  [('gram', 'usually'),
#   ('usually', 'run'),
#   ('run', 'like'),
#   ('like', 'ltgt'),
#   ('ltgt', 'half'),
#   ('half', 'eighth'),
#   ('eighth', 'smarter'),
#   ('smarter', 'though'),
#   ('though', 'get'),
#   ('get', 'almost'),
#   ('almost', 'whole'),
#   ('whole', 'second'),
#   ('second', 'gram'),
#   ('gram', 'ltgt')],
#  [('k', 'fyiha'),
#   ('fyiha', 'ride'),
#   ('ride', 'early'),
#   ('early', 'tomorrow'),
#   ('tomorrow', 'morning'),
#   ('morning', 'crashing'),
#   ('crashing', 'place'),
#   ('place', 'tonight')],
#  [('wow', 'never'),
#   ('never', 'realized'),
#   ('realized', 'embarassed'),
#   ('embarassed', 'accomodations'),
#   ('accomodations', 'thought'),
#   ('thought', 'liked'),
#   ('liked', 'since'),
#   ('since', 'wa'),
#   ('wa', 'best'),
#   ('best', 'could'),
#   ('could', 'always'),
#   ('always', 'seemed'),
#   ('seemed', 'happy'),
#   ('happy', 'cave'),
#   ('cave', 'im'),
#   ('im', 'sorry'),
#   ('sorry', 'didnt'),
#   ('didnt', 'dont'),
#   ('dont', 'give'),
#   ('give', 'im'),
#   ('im', 'sorry'),
#   ('sorry', 'offered'),
#   ('offered', 'im'),
#   ('im', 'sorry'),
#   ('sorry', 'room'),
#   ('room', 'wa'),
#   ('wa', 'embarassing')],
#  [('sm', 'ac'),
#   ('ac', 'sptv'),
#   ('sptv', 'new'),
#   ('new', 'jersey'),
#   ('jersey', 'devil'),
#   ('devil', 'detroit'),
#   ('detroit', 'red'),
#   ('red', 'wing'),
#   ('wing', 'play'),
#   ('play', 'ice'),
#   ('ice', 'hockey'),
#   ('hockey', 'correct'),
#   ('correct', 'incorrect'),
#   ('incorrect', 'end'),
#   ('end', 'reply'),
#   ('reply', 'end'),
#   ('end', 'sptv')],
#  [('know', 'mallika'),
#   ('mallika', 'sherawat'),
#   ('sherawat', 'yesterday'),
#   ('yesterday', 'find'),
#   ('find', 'lturlgt')],
#  [('congratsyear', 'special'),
#   ('special', 'cinema'),
#   ('cinema', 'pascall'),
#   ('pascall', '09061209465suprmanmatrix3'),
#   ('09061209465suprmanmatrix3', 'starwars3'),
#   ('starwars3', 'etcfree'),
#   ('etcfree', 'bx420ip45we'),
#   ('bx420ip45we', '150pm'),
#   ('150pm', 'dont'),
#   ('dont', 'miss')],
#  [('sorry', 'ill'), ('ill', 'call'), ('call', 'later'), ('later', 'meeting')],
#  [('tell', 'reached')],
#  [('yesgauti', 'sehwag'), ('sehwag', 'odi'), ('odi', 'series')],
#  [('gonna', 'pickburger'),
#   ('pickburger', 'way'),
#   ('way', 'home'),
#   ('home', 'cant'),
#   ('cant', 'even'),
#   ('even', 'move'),
#   ('move', 'pain'),
#   ('pain', 'killing')],
#  [('ha', 'ha'),
#   ('ha', 'ha'),
#   ('ha', 'good'),
#   ('good', 'joke'),
#   ('joke', 'girl'),
#   ('girl', 'situation'),
#   ('situation', 'seeker')],
#  [('part', 'checking'), ('checking', 'iq')],
#  [('sorry', 'roommate'),
#   ('roommate', 'took'),
#   ('took', 'forever'),
#   ('forever', 'ok'),
#   ('ok', 'come')],
#  [('ok', 'lar'),
#   ('lar', 'double'),
#   ('double', 'check'),
#   ('check', 'wif'),
#   ('wif', 'da'),
#   ('da', 'hair'),
#   ('hair', 'dresser'),
#   ('dresser', 'already'),
#   ('already', 'said'),
#   ('said', 'wun'),
#   ('wun', 'cutshort'),
#   ('cutshort', 'said'),
#   ('said', 'cut'),
#   ('cut', 'look'),
#   ('look', 'nice')],
#  [('valued', 'customer'),
#   ('customer', 'pleased'),
#   ('pleased', 'advise'),
#   ('advise', 'following'),
#   ('following', 'recent'),
#   ('recent', 'review'),
#   ('review', 'mob'),
#   ('mob', 'awarded'),
#   ('awarded', 'a1500'),
#   ('a1500', 'bonus'),
#   ('bonus', 'prize'),
#   ('prize', 'call'),
#   ('call', '09066364589')],
#  [('today', 'song'),
#   ('song', 'dedicated'),
#   ('dedicated', 'day'),
#   ('day', 'songdedicate'),
#   ('songdedicate', 'send'),
#   ('send', 'ur'),
#   ('ur', 'valuable'),
#   ('valuable', 'frnds'),
#   ('frnds', 'first'),
#   ('first', 'rply')],
#  [('urgent', 'ur'),
#   ('ur', 'awarded'),
#   ('awarded', 'complimentary'),
#   ('complimentary', 'trip'),
#   ('trip', 'eurodisinc'),
#   ('eurodisinc', 'trav'),
#   ('trav', 'acoentry41'),
#   ('acoentry41', 'a1000'),
#   ('a1000', 'claim'),
#   ('claim', 'txt'),
#   ('txt', 'dis'),
#   ('dis', '87121'),
#   ('87121', '186a150morefrmmob'),
#   ('186a150morefrmmob', 'shracomorsglsuplt10'),
#   ('shracomorsglsuplt10', 'ls1'),
#   ('ls1', '3aj')],
#  [('hear', 'new'),
#   ('new', 'divorce'),
#   ('divorce', 'barbie'),
#   ('barbie', 'come'),
#   ('come', 'ken'),
#   ('ken', 'stuff')],
#  [('plane', 'give'), ('give', 'month'), ('month', 'end')],
#  [('wah', 'lucky'),
#   ('lucky', 'man'),
#   ('man', 'save'),
#   ('save', 'money'),
#   ('money', 'hee')],
#  [('finished', 'class')],
#  [('hi', 'babe'),
#   ('babe', 'im'),
#   ('im', 'home'),
#   ('home', 'wanna'),
#   ('wanna', 'something'),
#   ('something', 'xx')],
#  [('kkwhere', 'youhow'), ('youhow', 'performed')],
#  [('u', 'call')],
#  [('waiting', 'machan'), ('machan', 'call'), ('call', 'free')],
#  [('thats', 'cool'),
#   ('cool', 'gentleman'),
#   ('gentleman', 'treat'),
#   ('treat', 'dignity'),
#   ('dignity', 'respect')],
#  [('like', 'people'), ('people', 'much'), ('much', 'shy'), ('shy', 'pa')],
#  [('doe', 'operate'), ('operate', 'ltgt')],
#  [('still', 'looking'),
#   ('looking', 'job'),
#   ('job', 'much'),
#   ('much', 'ta'),
#   ('ta', 'earn')],
#  [('sorry', 'ill'), ('ill', 'call'), ('call', 'later')],
#  [('k', 'call'), ('call', 'ah')],
#  [('ok', 'way'), ('way', 'home'), ('home', 'hi'), ('hi', 'hi')],
#  [('place', 'man')],
#  [('yup', 'next'), ('next', 'stop')],
#  [('call', 'later'),
#   ('later', 'dont'),
#   ('dont', 'network'),
#   ('network', 'urgnt'),
#   ('urgnt', 'sm')],
#  [('realgetting', 'yo'),
#   ('yo', 'needticket'),
#   ('needticket', 'one'),
#   ('one', 'jacket'),
#   ('jacket', 'im'),
#   ('im', 'done'),
#   ('done', 'already'),
#   ('already', 'used'),
#   ('used', 'multis')],
#  [('yes', 'started'),
#   ('started', 'send'),
#   ('send', 'request'),
#   ('request', 'make'),
#   ('make', 'pain'),
#   ('pain', 'came'),
#   ('came', 'back'),
#   ('back', 'im'),
#   ('im', 'back'),
#   ('back', 'bed'),
#   ('bed', 'double'),
#   ('double', 'coin'),
#   ('coin', 'factory'),
#   ('factory', 'gotta'),
#   ('gotta', 'cash'),
#   ('cash', 'nitros')],
#  [('im', 'really'),
#   ('really', 'still'),
#   ('still', 'tonight'),
#   ('tonight', 'babe')],
#  [('ela', 'kanoil'),
#   ('kanoil', 'download'),
#   ('download', 'come'),
#   ('come', 'wen'),
#   ('wen', 'ur'),
#   ('ur', 'free')],
#  [('yeah', 'donut'),
#   ('donut', 'stand'),
#   ('stand', 'close'),
#   ('close', 'tho'),
#   ('tho', 'youull'),
#   ('youull', 'catch'),
#   ('catch', 'something')],
#  [('sorry', 'pain'),
#   ('pain', 'ok'),
#   ('ok', 'meet'),
#   ('meet', 'another'),
#   ('another', 'night'),
#   ('night', 'spent'),
#   ('spent', 'late'),
#   ('late', 'afternoon'),
#   ('afternoon', 'casualty'),
#   ('casualty', 'mean'),
#   ('mean', 'havent'),
#   ('havent', 'done'),
#   ('done', 'stuff42moro'),
#   ('stuff42moro', 'includes'),
#   ('includes', 'time'),
#   ('time', 'sheet'),
#   ('sheet', 'sorry')],
#  [('smile', 'pleasure'),
#   ('pleasure', 'smile'),
#   ('smile', 'pain'),
#   ('pain', 'smile'),
#   ('smile', 'trouble'),
#   ('trouble', 'pours'),
#   ('pours', 'like'),
#   ('like', 'rain'),
#   ('rain', 'smile'),
#   ('smile', 'sum1'),
#   ('sum1', 'hurtsmile'),
#   ('hurtsmile', 'becoz'),
#   ('becoz', 'someone'),
#   ('someone', 'still'),
#   ('still', 'love'),
#   ('love', 'seesmiling')],
#  [('please', 'call'),
#   ('call', 'customer'),
#   ('customer', 'service'),
#   ('service', 'representative'),
#   ('representative', '0800'),
#   ('0800', '169'),
#   ('169', '6031'),
#   ('6031', '10am9pm'),
#   ('10am9pm', 'guaranteed'),
#   ('guaranteed', 'a1000'),
#   ('a1000', 'cash'),
#   ('cash', 'a5000'),
#   ('a5000', 'prize')],
#  [('havent', 'planning'),
#   ('planning', 'buy'),
#   ('buy', 'later'),
#   ('later', 'check'),
#   ('check', 'already'),
#   ('already', 'lido'),
#   ('lido', 'got'),
#   ('got', '530'),
#   ('530', 'showafternoonfinish'),
#   ('showafternoonfinish', 'work'),
#   ('work', 'already')],
#  [('free', 'ringtone'),
#   ('ringtone', 'waiting'),
#   ('waiting', 'collected'),
#   ('collected', 'simply'),
#   ('simply', 'text'),
#   ('text', 'password'),
#   ('password', 'mix'),
#   ('mix', '85069'),
#   ('85069', 'verify'),
#   ('verify', 'get'),
#   ('get', 'usher'),
#   ('usher', 'britney'),
#   ('britney', 'fml')],
#  [('watching', 'telugu'),
#   ('telugu', 'moviewat'),
#   ('moviewat', 'abt'),
#   ('abt', 'u')],
#  [('see', 'finish'), ('finish', 'load'), ('load', 'loan'), ('loan', 'pay')],
#  [('hi', 'wk'),
#   ('wk', 'ok'),
#   ('ok', 'hols'),
#   ('hols', 'yes'),
#   ('yes', 'bit'),
#   ('bit', 'run'),
#   ('run', 'forgot'),
#   ('forgot', 'hairdresser'),
#   ('hairdresser', 'appointment'),
#   ('appointment', 'four'),
#   ('four', 'need'),
#   ('need', 'get'),
#   ('get', 'homeshower'),
#   ('homeshower', 'beforehand'),
#   ('beforehand', 'doe'),
#   ('doe', 'cause'),
#   ('cause', 'probham')],
#  [('please', 'dont'),
#   ('dont', 'text'),
#   ('text', 'anymore'),
#   ('anymore', 'nothing'),
#   ('nothing', 'else'),
#   ('else', 'say')],
#  [('okay', 'name'),
#   ('name', 'ur'),
#   ('ur', 'price'),
#   ('price', 'long'),
#   ('long', 'legal'),
#   ('legal', 'wen'),
#   ('wen', 'pickavexx')],
#  [('im', 'still'),
#   ('still', 'looking'),
#   ('looking', 'car'),
#   ('car', 'buy'),
#   ('buy', 'gone'),
#   ('gone', '4the'),
#   ('4the', 'driving'),
#   ('driving', 'test'),
#   ('test', 'yet')],
#  [('per', 'request'),
#   ('request', 'melle'),
#   ('melle', 'melle'),
#   ('melle', 'oru'),
#   ('oru', 'minnaminunginte'),
#   ('minnaminunginte', 'nurungu'),
#   ('nurungu', 'vettam'),
#   ('vettam', 'ha'),
#   ('ha', 'set'),
#   ('set', 'callertune'),
#   ('callertune', 'caller'),
#   ('caller', 'presscopy'),
#   ('presscopy', 'friend'),
#   ('friend', 'callertune')],
#  [('wow', 'youre'),
#   ('youre', 'right'),
#   ('right', 'didnt'),
#   ('didnt', 'mean'),
#   ('mean', 'guess'),
#   ('guess', 'gave'),
#   ('gave', 'boston'),
#   ('boston', 'men'),
#   ('men', 'changed'),
#   ('changed', 'search'),
#   ('search', 'location'),
#   ('location', 'nyc'),
#   ('nyc', 'something'),
#   ('something', 'changed'),
#   ('changed', 'cuz'),
#   ('cuz', 'signin'),
#   ('signin', 'page'),
#   ('page', 'still'),
#   ('still', 'say'),
#   ('say', 'boston')],
#  [('umma', 'life'),
#   ('life', 'vava'),
#   ('vava', 'umma'),
#   ('umma', 'love'),
#   ('love', 'lot'),
#   ('lot', 'dear')],
#  [('thanks', 'lot'),
#   ('lot', 'wish'),
#   ('wish', 'birthday'),
#   ('birthday', 'thanks'),
#   ('thanks', 'making'),
#   ('making', 'birthday'),
#   ('birthday', 'truly'),
#   ('truly', 'memorable')],
#  [('aight', 'ill'), ('ill', 'hit'), ('hit', 'get'), ('get', 'cash')],
#  [('would', 'ip'),
#   ('ip', 'address'),
#   ('address', 'test'),
#   ('test', 'considering'),
#   ('considering', 'computer'),
#   ('computer', 'isnt'),
#   ('isnt', 'minecraft'),
#   ('minecraft', 'server')],
#  [('know', 'grumpy'),
#   ('grumpy', 'old'),
#   ('old', 'people'),
#   ('people', 'mom'),
#   ('mom', 'wa'),
#   ('wa', 'like'),
#   ('like', 'better'),
#   ('better', 'lying'),
#   ('lying', 'always'),
#   ('always', 'one'),
#   ('one', 'play'),
#   ('play', 'joke')],
#  [('dont', 'worry'), ('worry', 'guess'), ('guess', 'busy')],
#  [('plural', 'noun'), ('noun', 'research')],
#  [('going', 'dinnermsg')],
#  [('im', 'ok'),
#   ('ok', 'wif'),
#   ('wif', 'co'),
#   ('co', 'liketry'),
#   ('liketry', 'new'),
#   ('new', 'thing'),
#   ('thing', 'scareddun'),
#   ('scareddun', 'like'),
#   ('like', 'mah'),
#   ('mah', 'cosaid'),
#   ('cosaid', 'loud')],
#  [('gent', 'trying'),
#   ('trying', 'contact'),
#   ('contact', 'last'),
#   ('last', 'weekend'),
#   ('weekend', 'draw'),
#   ('draw', 'show'),
#   ('show', 'a1000'),
#   ('a1000', 'prize'),
#   ('prize', 'guaranteed'),
#   ('guaranteed', 'call'),
#   ('call', '09064012160'),
#   ('09064012160', 'claim'),
#   ('claim', 'code'),
#   ('code', 'k52'),
#   ('k52', 'valid'),
#   ('valid', '12hrs'),
#   ('12hrs', '150ppm')],
#  [('wa', 'ur'),
#   ('ur', 'openin'),
#   ('openin', 'sentence'),
#   ('sentence', 'formal'),
#   ('formal', 'anyway'),
#   ('anyway', 'im'),
#   ('im', 'fine'),
#   ('fine', 'juz'),
#   ('juz', 'tt'),
#   ('tt', 'im'),
#   ('im', 'eatin'),
#   ('eatin', 'muchputtin'),
#   ('muchputtin', 'weighthaha'),
#   ('weighthaha', 'anythin'),
#   ('anythin', 'special'),
#   ('special', 'happened')],
#  [('entered', 'cabin'),
#   ('cabin', 'pa'),
#   ('pa', 'said'),
#   ('said', 'happy'),
#   ('happy', 'bday'),
#   ('bday', 'bos'),
#   ('bos', 'felt'),
#   ('felt', 'special'),
#   ('special', 'askdlunch'),
#   ('askdlunch', 'lunch'),
#   ('lunch', 'invited'),
#   ('invited', 'apartment'),
#   ('apartment', 'went')],
#  [('winnerspecially', 'selectedreceive'),
#   ('selectedreceive', 'a1000holiday'),
#   ('a1000holiday', 'flight'),
#   ('flight', 'inc'),
#   ('inc', 'speak'),
#   ('speak', 'live'),
#   ('live', 'operatorclaim'),
#   ('operatorclaim', '0871277810910pmin'),
#   ('0871277810910pmin', '18')],
#  [('goodo', 'yes'),
#   ('yes', 'must'),
#   ('must', 'speak'),
#   ('speak', 'friday'),
#   ('friday', 'eggpotato'),
#   ('eggpotato', 'ratio'),
#   ('ratio', 'tortilla'),
#   ('tortilla', 'needed')],
#  [('hmmmy', 'uncle'),
#   ('uncle', 'informed'),
#   ('informed', 'paying'),
#   ('paying', 'school'),
#   ('school', 'directly'),
#   ('directly', 'pls'),
#   ('pls', 'buy'),
#   ('buy', 'food')],
#  [('private', '2004'),
#   ('2004', 'account'),
#   ('account', 'statement'),
#   ('statement', '07742676969'),
#   ('07742676969', 'show'),
#   ('show', '786'),
#   ('786', 'unredeemed'),
#   ('unredeemed', 'bonus'),
#   ('bonus', 'point'),
#   ('point', 'claim'),
#   ('claim', 'call'),
#   ('call', '08719180248'),
#   ('08719180248', 'identifier'),
#   ('identifier', 'code'),
#   ('code', '45239'),
#   ('45239', 'expires')],
#  [('urgent', 'mobile'),
#   ('mobile', 'wa'),
#   ('wa', 'awarded'),
#   ('awarded', 'a2000'),
#   ('a2000', 'bonus'),
#   ('bonus', 'caller'),
#   ('caller', 'prize'),
#   ('prize', '5903'),
#   ('5903', 'final'),
#   ('final', 'try'),
#   ('try', 'contactcall'),
#   ('contactcall', 'landline'),
#   ('landline', '09064019788'),
#   ('09064019788', 'box42wr29c'),
#   ('box42wr29c', '150ppm')],
#  [('new', 'address'),
#   ('address', 'applespairsall'),
#   ('applespairsall', 'malarky')],
#  [('today', 'voda'),
#   ('voda', 'number'),
#   ('number', 'ending'),
#   ('ending', '7548'),
#   ('7548', 'selected'),
#   ('selected', 'receive'),
#   ('receive', '350'),
#   ('350', 'award'),
#   ('award', 'match'),
#   ('match', 'please'),
#   ('please', 'call'),
#   ('call', '08712300220'),
#   ('08712300220', 'quoting'),
#   ('quoting', 'claim'),
#   ('claim', 'code'),
#   ('code', '4041'),
#   ('4041', 'standard'),
#   ('standard', 'rate'),
#   ('rate', 'app')],
#  [('going', 'sao'),
#   ('sao', 'mu'),
#   ('mu', 'today'),
#   ('today', 'done'),
#   ('done', '12')],
#  [('ii', 'predict'),
#   ('predict', 'wat'),
#   ('wat', 'time'),
#   ('time', 'ill'),
#   ('ill', 'finish'),
#   ('finish', 'buying')],
#  [('good', 'stuff')],
#  [('knowyetunde', 'hasnt'),
#   ('hasnt', 'sent'),
#   ('sent', 'money'),
#   ('money', 'yet'),
#   ('yet', 'sent'),
#   ('sent', 'text'),
#   ('text', 'bother'),
#   ('bother', 'sending'),
#   ('sending', 'dont'),
#   ('dont', 'involve'),
#   ('involve', 'anything'),
#   ('anything', 'shouldnt'),
#   ('shouldnt', 'imposed'),
#   ('imposed', 'anything'),
#   ('anything', 'first'),
#   ('first', 'place'),
#   ('place', 'apologise')],
#  [],
#  [('hey', 'girlu'),
#   ('girlu', 'hoper'),
#   ('hoper', 'well'),
#   ('well', 'delbak'),
#   ('delbak', 'long'),
#   ('long', 'timegive'),
#   ('timegive', 'call'),
#   ('call', 'sum'),
#   ('sum', 'time'),
#   ('time', 'lucyxx')],
#  [('kkhow', 'much'), ('much', 'doe'), ('doe', 'cost')],
#  [('im', 'home')],
#  [('dear', 'call'), ('call', 'tmorrowpls'), ('tmorrowpls', 'accomodate')],
#  [('first', 'answer'), ('answer', 'question')],
#  [('sunshine', 'quiz'),
#   ('quiz', 'wklywin'),
#   ('wklywin', 'top'),
#   ('top', 'sony'),
#   ('sony', 'dvd'),
#   ('dvd', 'playerknow'),
#   ('playerknow', 'country'),
#   ('country', 'algarve'),
#   ('algarve', 'txt'),
#   ('txt', 'ansr'),
#   ('ansr', '82277'),
#   ('82277', 'a150'),
#   ('a150', 'sptyrone')],
#  [('wantget', 'laid'),
#   ('laid', 'tonight'),
#   ('tonight', 'want'),
#   ('want', 'real'),
#   ('real', 'dogging'),
#   ('dogging', 'location'),
#   ('location', 'sent'),
#   ('sent', 'directur'),
#   ('directur', 'mob'),
#   ('mob', 'join'),
#   ('join', 'uk'),
#   ('uk', 'largest'),
#   ('largest', 'dogging'),
#   ('dogging', 'network'),
#   ('network', 'bt'),
#   ('bt', 'txting'),
#   ('txting', 'gravel'),
#   ('gravel', '69888'),
#   ('69888', 'nt'),
#   ('nt', 'ec2a'),
#   ('ec2a', '31pmsg150p')],
#  [('haf', 'msn'), ('msn', 'yijuehotmailcom')],
#  [('call', 'meet')],
#  [('check', 'room'), ('room', 'befor'), ('befor', 'activity')],
#  [('youll', 'rcv'),
#   ('rcv', 'msg'),
#   ('msg', 'chat'),
#   ('chat', 'svc'),
#   ('svc', 'free'),
#   ('free', 'hardcore'),
#   ('hardcore', 'service'),
#   ('service', 'text'),
#   ('text', 'go'),
#   ('go', '69988get'),
#   ('69988get', 'nothingmust'),
#   ('nothingmust', 'age'),
#   ('age', 'verify'),
#   ('verify', 'yr'),
#   ('yr', 'network'),
#   ('network', 'try')],
#  [('gotlazy', 'type'),
#   ('type', 'forgot'),
#   ('forgot', 'lect'),
#   ('lect', 'saw'),
#   ('saw', 'pouch'),
#   ('pouch', 'likenice')],
#  [('k', 'text'), ('text', 'youre'), ('youre', 'way')],
#  [('sir', 'waiting'), ('waiting', 'mail')],
#  [('swt', 'thought'),
#   ('thought', 'nver'),
#   ('nver', 'get'),
#   ('get', 'tired'),
#   ('tired', 'little'),
#   ('little', 'thinglovable'),
#   ('thinglovable', 'person'),
#   ('person', 'cozsomtimes'),
#   ('cozsomtimes', 'little'),
#   ('little', 'thing'),
#   ('thing', 'occupy'),
#   ('occupy', 'biggest'),
#   ('biggest', 'part'),
#   ('part', 'heart'),
#   ('heart', 'gud'),
#   ('gud', 'ni8')],
#  [('know', 'pls'), ('pls', 'open'), ('open', 'back')],
#  [('yes', 'see'), ('see', 'ya'), ('ya', 'dot')],
#  [('whats', 'staff'),
#   ('staff', 'name'),
#   ('name', 'taking'),
#   ('taking', 'class'),
#   ('class', 'u')],
#  [('freemsg', 'havent'),
#   ('havent', 'replied'),
#   ('replied', 'text'),
#   ('text', 'im'),
#   ('im', 'randy'),
#   ('randy', 'sexy'),
#   ('sexy', 'female'),
#   ('female', 'live'),
#   ('live', 'local'),
#   ('local', 'luv'),
#   ('luv', 'hearnetcollex'),
#   ('hearnetcollex', 'ltd'),
#   ('ltd', '08700621170150p'),
#   ('08700621170150p', 'per'),
#   ('per', 'msg'),
#   ('msg', 'reply'),
#   ('reply', 'stop'),
#   ('stop', 'end')],
#  [('ummmawill', 'call'),
#   ('call', 'check'),
#   ('check', 'inour'),
#   ('inour', 'life'),
#   ('life', 'begin'),
#   ('begin', 'qatar'),
#   ('qatar', 'pls'),
#   ('pls', 'pray'),
#   ('pray', 'hard')],
#  [('ki', 'deleted'), ('deleted', 'contact')],
#  [('sindu', 'got'), ('got', 'job'), ('job', 'birla'), ('birla', 'soft')],
#  [('wine', 'flowing'), ('flowing', 'im'), ('im', 'nevering')],
#  [('yup', 'thk'),
#   ('thk', 'cine'),
#   ('cine', 'better'),
#   ('better', 'co'),
#   ('co', 'needgoplaza'),
#   ('needgoplaza', 'mah')],
#  [('ok', 'ur'), ('ur', 'typical'), ('typical', 'reply')],
#  [('per', 'request'),
#   ('request', 'melle'),
#   ('melle', 'melle'),
#   ('melle', 'oru'),
#   ('oru', 'minnaminunginte'),
#   ('minnaminunginte', 'nurungu'),
#   ('nurungu', 'vettam'),
#   ('vettam', 'ha'),
#   ('ha', 'set'),
#   ('set', 'callertune'),
#   ('callertune', 'caller'),
#   ('caller', 'presscopy'),
#   ('presscopy', 'friend'),
#   ('friend', 'callertune')],
#  [('everywhere', 'dirt'),
#   ('dirt', 'floor'),
#   ('floor', 'window'),
#   ('window', 'even'),
#   ('even', 'shirt'),
#   ('shirt', 'sometimes'),
#   ('sometimes', 'open'),
#   ('open', 'mouth'),
#   ('mouth', 'come'),
#   ('come', 'flowing'),
#   ('flowing', 'dream'),
#   ('dream', 'world'),
#   ('world', 'without'),
#   ('without', 'half'),
#   ('half', 'chore'),
#   ('chore', 'time'),
#   ('time', 'joy'),
#   ('joy', 'lot'),
#   ('lot', 'tv'),
#   ('tv', 'show'),
#   ('show', 'ill'),
#   ('ill', 'see'),
#   ('see', 'guess'),
#   ('guess', 'like'),
#   ('like', 'thing'),
#   ('thing', 'must'),
#   ('must', 'exist'),
#   ('exist', 'like'),
#   ('like', 'rain'),
#   ('rain', 'hail'),
#   ('hail', 'mist'),
#   ('mist', 'time'),
#   ('time', 'done'),
#   ('done', 'become'),
#   ('become', 'one')],
#  [('aaooooright', 'work')],
#  [('im', 'leaving'), ('leaving', 'house')],
#  [('hello', 'love'),
#   ('love', 'get'),
#   ('get', 'interview'),
#   ('interview', 'today'),
#   ('today', 'happy'),
#   ('happy', 'good'),
#   ('good', 'boy'),
#   ('boy', 'think'),
#   ('think', 'meare'),
#   ('meare', 'missing')],
#  [('customer', 'service'),
#   ('service', 'annoncement'),
#   ('annoncement', 'new'),
#   ('new', 'year'),
#   ('year', 'delivery'),
#   ('delivery', 'waiting'),
#   ('waiting', 'please'),
#   ('please', 'call'),
#   ('call', '07046744435'),
#   ('07046744435', 'arrange'),
#   ('arrange', 'delivery')],
#  [('winnerspecially', 'selectedreceive'),
#   ('selectedreceive', 'a1000'),
#   ('a1000', 'cashholiday'),
#   ('cashholiday', 'flight'),
#   ('flight', 'inc'),
#   ('inc', 'speak'),
#   ('speak', 'live'),
#   ('live', 'operatorclaim'),
#   ('operatorclaim', '0871277810810')],
#  [('keep', 'safe'),
#   ('safe', 'need'),
#   ('need', 'miss'),
#   ('miss', 'already'),
#   ('already', 'envy'),
#   ('envy', 'everyone'),
#   ('everyone', 'see'),
#   ('see', 'real'),
#   ('real', 'life')],
#  [('new', 'car'),
#   ('car', 'house'),
#   ('house', 'parentsi'),
#   ('parentsi', 'new'),
#   ('new', 'job'),
#   ('job', 'hand')],
#  [('im', 'love'),
#   ('love', 'im'),
#   ('im', 'excited'),
#   ('excited', 'day'),
#   ('day', 'spend'),
#   ('spend', 'make'),
#   ('make', 'happy')],
#  [('pls', 'stop'),
#   ('stop', 'bootydelious'),
#   ('bootydelious', '32f'),
#   ('32f', 'inviting'),
#   ('inviting', 'friend'),
#   ('friend', 'reply'),
#   ('reply', 'yes434'),
#   ('yes434', 'no434'),
#   ('no434', 'see'),
#   ('see', 'wwwsmsacubootydelious'),
#   ('wwwsmsacubootydelious', 'stop'),
#   ('stop', 'send'),
#   ('send', 'stop'),
#   ('stop', 'frnd'),
#   ('frnd', '62468')],
#  [('bangbabes', 'ur'),
#   ('ur', 'order'),
#   ('order', 'wayreceive'),
#   ('wayreceive', 'service'),
#   ('service', 'msgdownload'),
#   ('msgdownload', 'ur'),
#   ('ur', 'contentgoto'),
#   ('contentgoto', 'wap'),
#   ('wap', 'bangb'),
#   ('bangb', 'tv'),
#   ('tv', 'ur'),
#   ('ur', 'mobile'),
#   ('mobile', 'internetservice'),
#   ('internetservice', 'menu')],
#  [('place', 'ur'),
#   ('ur', 'pointculture'),
#   ('pointculture', 'module'),
#   ('module', 'already')],
#  [('urgent', 'trying'),
#   ('trying', 'contact'),
#   ('contact', 'last'),
#   ('last', 'weekend'),
#   ('weekend', 'draw'),
#   ('draw', 'show'),
#   ('show', 'a900'),
#   ('a900', 'prize'),
#   ('prize', 'guaranteed'),
#   ('guaranteed', 'call'),
#   ('call', '09061701939'),
#   ('09061701939', 'claim'),
#   ('claim', 'code'),
#   ('code', 's89'),
#   ('s89', 'valid'),
#   ('valid', '12hrs')],
#  [('hi', 'frnd'),
#   ('frnd', 'best'),
#   ('best', 'way'),
#   ('way', 'avoid'),
#   ('avoid', 'missunderstding'),
#   ('missunderstding', 'wit'),
#   ('wit', 'beloved'),
#   ('beloved', 'one')],
#  [('great', 'escape'),
#   ('escape', 'fancy'),
#   ('fancy', 'bridge'),
#   ('bridge', 'need'),
#   ('need', 'lager'),
#   ('lager', 'see'),
#   ('see', 'tomo')],
#  [('yes', 'completely'),
#   ('completely', 'formclark'),
#   ('formclark', 'also'),
#   ('also', 'utter'),
#   ('utter', 'waste')],
#  [('sir', 'need'),
#   ('need', 'axis'),
#   ('axis', 'bank'),
#   ('bank', 'account'),
#   ('account', 'bank'),
#   ('bank', 'address')],
#  [('hmmm', 'thk'),
#   ('thk', 'sure'),
#   ('sure', 'got'),
#   ('got', 'time'),
#   ('time', 'hop'),
#   ('hop', 'ard'),
#   ('ard', 'ya'),
#   ('ya', 'gofree'),
#   ('gofree', 'abt'),
#   ('abt', 'muz'),
#   ('muz', 'calldiscus'),
#   ('calldiscus', 'liao')],
#  [('time', 'coming'), ('coming', 'later')],
#  [('bloody', 'hell'),
#   ('hell', 'cant'),
#   ('cant', 'believe'),
#   ('believe', 'forgot'),
#   ('forgot', 'surname'),
#   ('surname', 'mr'),
#   ('mr', 'ill'),
#   ('ill', 'giveclue'),
#   ('giveclue', 'spanish'),
#   ('spanish', 'begin')],
#  [('well', 'im'),
#   ('im', 'gonna'),
#   ('gonna', 'finish'),
#   ('finish', 'bath'),
#   ('bath', 'goodfine'),
#   ('goodfine', 'night')],
#  [('let', 'know'),
#   ('know', 'youve'),
#   ('youve', 'got'),
#   ('got', 'money'),
#   ('money', 'carlos'),
#   ('carlos', 'make'),
#   ('make', 'call')],
#  [('u', 'still'), ('still', 'going'), ('going', 'mall')],
#  [('turn', 'friend'),
#   ('friend', 'staying'),
#   ('staying', 'whole'),
#   ('whole', 'show'),
#   ('show', 'wont'),
#   ('wont', 'back'),
#   ('back', 'til'),
#   ('til', 'ltgt'),
#   ('ltgt', 'feel'),
#   ('feel', 'free'),
#   ('free', 'go'),
#   ('go', 'ahead'),
#   ('ahead', 'smoke'),
#   ('smoke', 'ltgt'),
#   ('ltgt', 'worth')],
#  [('text', 'doesnt'),
#   ('doesnt', 'reply'),
#   ('reply', 'let'),
#   ('let', 'know'),
#   ('know', 'log')],
#  [('hi', 'spoke'),
#   ('spoke', 'maneeshawed'),
#   ('maneeshawed', 'like'),
#   ('like', 'know'),
#   ('know', 'satisfied'),
#   ('satisfied', 'experience'),
#   ('experience', 'reply'),
#   ('reply', 'toll'),
#   ('toll', 'free'),
#   ('free', 'yes')],
#  [('lifted', 'hope'),
#   ('hope', 'offer'),
#   ('offer', 'money'),
#   ('money', 'need'),
#   ('need', 'especially'),
#   ('especially', 'end'),
#   ('end', 'month'),
#   ('month', 'approach'),
#   ('approach', 'hurt'),
#   ('hurt', 'studying'),
#   ('studying', 'anyways'),
#   ('anyways', 'gr8'),
#   ('gr8', 'weekend')],
#  [],
#  [('ok', 'gentleman'),
#   ('gentleman', 'treat'),
#   ('treat', 'dignity'),
#   ('dignity', 'respect')],
#  [('guy', 'close')],
#  [('going', 'nothing'), ('nothing', 'greatbye')],
#  [('hello', 'handsome'),
#   ('handsome', 'finding'),
#   ('finding', 'job'),
#   ('job', 'lazy'),
#   ('lazy', 'working'),
#   ('working', 'towards'),
#   ('towards', 'getting'),
#   ('getting', 'back'),
#   ('back', 'net'),
#   ('net', 'mummy'),
#   ('mummy', 'wheres'),
#   ('wheres', 'boytoy'),
#   ('boytoy', 'doe'),
#   ('doe', 'miss')],
#  [('haha', 'awesome'), ('awesome', 'minute')],
#  [('please', 'call'),
#   ('call', 'customer'),
#   ('customer', 'service'),
#   ('service', 'representative'),
#   ('representative', 'freephone'),
#   ('freephone', '0808'),
#   ('0808', '145'),
#   ('145', '4742'),
#   ('4742', '9am11pm'),
#   ('9am11pm', 'guaranteed'),
#   ('guaranteed', 'a1000'),
#   ('a1000', 'cash'),
#   ('cash', 'a5000'),
#   ('a5000', 'prize')],
#  [('got', 'xmas'), ('xmas', 'radio'), ('radio', 'time'), ('time', 'get')],
#  [('jus', 'reached'),
#   ('reached', 'home'),
#   ('home', 'go'),
#   ('go', 'bathe'),
#   ('bathe', 'first'),
#   ('first', 'si'),
#   ('si', 'using'),
#   ('using', 'net'),
#   ('net', 'tellfinish'),
#   ('tellfinish', 'k')],
#  [('unique', 'enough'),
#   ('enough', 'find'),
#   ('find', '30th'),
#   ('30th', 'august'),
#   ('august', 'wwwareyouuniquecouk')],
#  [('im', 'sorry'),
#   ('sorry', 'ive'),
#   ('ive', 'joined'),
#   ('joined', 'league'),
#   ('league', 'people'),
#   ('people', 'dont'),
#   ('dont', 'keep'),
#   ('keep', 'touch'),
#   ('touch', 'mean'),
#   ('mean', 'great'),
#   ('great', 'deal'),
#   ('deal', 'friend'),
#   ('friend', 'time'),
#   ('time', 'even'),
#   ('even', 'great'),
#   ('great', 'personal'),
#   ('personal', 'cost'),
#   ('cost', 'great'),
#   ('great', 'week')],
#  [('hi', 'finally'), ('finally', 'completed'), ('completed', 'course')],
#  [('stop', 'however'),
#   ('however', 'suggest'),
#   ('suggest', 'stay'),
#   ('stay', 'someone'),
#   ('someone', 'able'),
#   ('able', 'give'),
#   ('give', 'every'),
#   ('every', 'stool')],
#  [('hope', 'youve'),
#   ('youve', 'settled'),
#   ('settled', 'new'),
#   ('new', 'school'),
#   ('school', 'year'),
#   ('year', 'wishin'),
#   ('wishin', 'gr8'),
#   ('gr8', 'day')],
#  [('gud', 'mrng'),
#   ('mrng', 'dear'),
#   ('dear', 'hav'),
#   ('hav', 'nice'),
#   ('nice', 'day')],
#  [('u', 'got'), ('got', 'person'), ('person', 'story')],
#  [('hamster', 'dead'),
#   ('dead', 'hey'),
#   ('hey', 'tmr'),
#   ('tmr', 'meet'),
#   ('meet', '1pm'),
#   ('1pm', 'orchard'),
#   ('orchard', 'mrt')],
#  [('hi', 'kate'),
#   ('kate', 'evening'),
#   ('evening', 'hope'),
#   ('hope', 'see'),
#   ('see', 'tomorrow'),
#   ('tomorrow', 'bit'),
#   ('bit', 'bloody'),
#   ('bloody', 'babyjontet'),
#   ('babyjontet', 'txt'),
#   ('txt', 'backxxx')],
#  [('found', 'enc'), ('enc', 'ltgt')],
#  [('sent', 'ltgt'), ('ltgt', 'buck')],
#  [('hello', 'darlin'),
#   ('darlin', 'ive'),
#   ('ive', 'finished'),
#   ('finished', 'college'),
#   ('college', 'txtfinishlove'),
#   ('txtfinishlove', 'kate'),
#   ('kate', 'xxx')],
#  [('account', 'ha'),
#   ('ha', 'refilled'),
#   ('refilled', 'successfully'),
#   ('successfully', 'inr'),
#   ('inr', 'ltdecimalgt'),
#   ('ltdecimalgt', 'keralacircle'),
#   ('keralacircle', 'prepaid'),
#   ('prepaid', 'account'),
#   ('account', 'balanceltdecimalgt'),
#   ('balanceltdecimalgt', 'transaction'),
#   ('transaction', 'id'),
#   ('id', 'kr'),
#   ('kr', 'ltgt')],
#  [('goodmorning', 'sleeping'), ('sleeping', 'ga')],
#  [('u', 'call'), ('call', 'alter'), ('alter', '11'), ('11', 'ok')],
#  [('ii', 'say'),
#   ('say', 'like'),
#   ('like', 'dat'),
#   ('dat', 'dun'),
#   ('dun', 'buy'),
#   ('buy', 'ericsson'),
#   ('ericsson', 'oso'),
#   ('oso', 'cannot'),
#   ('cannot', 'oredi'),
#   ('oredi', 'lar')],
#  [('entered', 'cabin'),
#   ('cabin', 'pa'),
#   ('pa', 'said'),
#   ('said', 'happy'),
#   ('happy', 'bday'),
#   ('bday', 'bos'),
#   ('bos', 'felt'),
#   ('felt', 'special'),
#   ('special', 'askdlunch'),
#   ('askdlunch', 'lunch'),
#   ('lunch', 'invited'),
#   ('invited', 'apartment'),
#   ('apartment', 'went')],
#  [('aight', 'yo'), ('yo', 'dat'), ('dat', 'straight'), ('straight', 'dogg')],
#  [('please', 'giveconnection'),
#   ('giveconnection', 'today'),
#   ('today', 'ltdecimalgt'),
#   ('ltdecimalgt', 'refund'),
#   ('refund', 'bill')],
#  [('shoot', 'big'), ('big', 'load'), ('load', 'get'), ('get', 'ready')],
#  [('whats', 'bruv'),
#   ('bruv', 'hope'),
#   ('hope', 'great'),
#   ('great', 'break'),
#   ('break', 'rewarding'),
#   ('rewarding', 'semester')],
#  [('home', 'always'), ('always', 'chat')],
#  [('kkgoodstudy', 'well')],
#  [('yup', 'noe'), ('noe', 'leh')],
#  [('sound', 'great'), ('great', 'home')],
#  [('finally', 'match'),
#   ('match', 'heading'),
#   ('heading', 'towards'),
#   ('towards', 'draw'),
#   ('draw', 'prediction')],
#  [('tired', 'havent'),
#   ('havent', 'slept'),
#   ('slept', 'well'),
#   ('well', 'past'),
#   ('past', 'night')],
#  [('easy', 'ahsen'),
#   ('ahsen', 'got'),
#   ('got', 'selected'),
#   ('selected', 'mean'),
#   ('mean', 'good')],
#  [('take', 'exam'), ('exam', 'march'), ('march', '3')],
#  [('yeah', 'think'),
#   ('think', 'use'),
#   ('use', 'gt'),
#   ('gt', 'atm'),
#   ('atm', 'register'),
#   ('register', 'sure'),
#   ('sure', 'anyway'),
#   ('anyway', 'help'),
#   ('help', 'let'),
#   ('let', 'know'),
#   ('know', 'sure'),
#   ('sure', 'ready')],
#  [('ok', 'prob'), ('prob', 'take'), ('take', 'ur'), ('ur', 'time')],
#  [('called', 'ubandu'),
#   ('ubandu', 'run'),
#   ('run', 'without'),
#   ('without', 'installing'),
#   ('installing', 'hard'),
#   ('hard', 'diskyou'),
#   ('diskyou', 'use'),
#   ('use', 'copy'),
#   ('copy', 'important'),
#   ('important', 'file'),
#   ('file', 'system'),
#   ('system', 'give'),
#   ('give', 'repair'),
#   ('repair', 'shop')],
#  [('sorry', 'ill'), ('ill', 'call'), ('call', 'later')],
#  [('u', 'say'),
#   ('say', 'leh'),
#   ('leh', 'course'),
#   ('course', 'nothing'),
#   ('nothing', 'happen'),
#   ('happen', 'lar'),
#   ('lar', 'sayromantic'),
#   ('sayromantic', 'jus'),
#   ('jus', 'bit'),
#   ('bit', 'lor'),
#   ('lor', 'thknite'),
#   ('thknite', 'scenery'),
#   ('scenery', 'nice'),
#   ('nice', 'leh')],
#  [('500', 'new'),
#   ('new', 'mobile'),
#   ('mobile', '2004'),
#   ('2004', 'must'),
#   ('must', 'go'),
#   ('go', 'txt'),
#   ('txt', 'nokia'),
#   ('nokia', '89545'),
#   ('89545', 'collect'),
#   ('collect', 'todayfrom'),
#   ('todayfrom', 'a1'),
#   ('a1', 'www4tcbiz'),
#   ('www4tcbiz', '2optout'),
#   ('2optout', '08718726270150gbpmtmsg18')],
#  [('would', 'really'),
#   ('really', 'appreciate'),
#   ('appreciate', 'call'),
#   ('call', 'need'),
#   ('need', 'someone'),
#   ('someone', 'talk')],
#  [('u', 'meet'),
#   ('meet', 'ur'),
#   ('ur', 'dream'),
#   ('dream', 'partner'),
#   ('partner', 'soon'),
#   ('soon', 'ur'),
#   ('ur', 'careerflyng'),
#   ('careerflyng', 'startfind'),
#   ('startfind', 'free'),
#   ('free', 'txt'),
#   ('txt', 'horo'),
#   ('horo', 'followed'),
#   ('followed', 'ur'),
#   ('ur', 'star'),
#   ('star', 'signg'),
#   ('signg', 'horo'),
#   ('horo', 'aries')],
#  [('hey', 'company'),
#   ('company', 'elama'),
#   ('elama', 'po'),
#   ('po', 'mudyadhu')],
#  [('life', 'strict'),
#   ('strict', 'teacher'),
#   ('teacher', 'bcoz'),
#   ('bcoz', 'teacher'),
#   ('teacher', 'teach'),
#   ('teach', 'lesson'),
#   ('lesson', 'amp'),
#   ('amp', 'conduct'),
#   ('conduct', 'exam'),
#   ('exam', 'life'),
#   ('life', 'first'),
#   ('first', 'conduct'),
#   ('conduct', 'exam'),
#   ('exam', 'amp'),
#   ('amp', 'teach'),
#   ('teach', 'lesson'),
#   ('lesson', 'happy'),
#   ('happy', 'morning')],
#  [('dear', 'good'), ('good', 'morning')],
#  [('get', 'gandhipuram'),
#   ('gandhipuram', 'walk'),
#   ('walk', 'cross'),
#   ('cross', 'cut'),
#   ('cut', 'road'),
#   ('road', 'right'),
#   ('right', 'side'),
#   ('side', 'ltgt'),
#   ('ltgt', 'street'),
#   ('street', 'road'),
#   ('road', 'turn'),
#   ('turn', 'first'),
#   ('first', 'right')],
#  [('dear', 'going'), ('going', 'rubber'), ('rubber', 'place')],
#  [('sorry', 'battery'), ('battery', 'died'), ('died', 'yeah'), ('yeah', 'im')],
#  [('yeshere', 'tv'),
#   ('tv', 'always'),
#   ('always', 'available'),
#   ('available', 'work'),
#   ('work', 'place')],
#  [('text', 'meet'),
#   ('meet', 'someone'),
#   ('someone', 'sexy'),
#   ('sexy', 'todayfind'),
#   ('todayfind', 'date'),
#   ('date', 'even'),
#   ('even', 'flirtjoin10p'),
#   ('flirtjoin10p', 'reply'),
#   ('reply', 'name'),
#   ('name', 'age'),
#   ('age', 'eg'),
#   ('eg', 'sam'),
#   ('sam', '25'),
#   ('25', '18'),
#   ('18', 'msg'),
#   ('msg', 'recdthirtyeight'),
#   ('recdthirtyeight', 'penny')],
#  [('printed', 'oh'), ('oh', 'ltgt'), ('ltgt', 'come'), ('come', 'upstairs')],
#  [('ill', 'little'),
#   ('little', 'closer'),
#   ('closer', 'like'),
#   ('like', 'bus'),
#   ('bus', 'stop'),
#   ('stop', 'street')],
#  [('youwhen', 'wil'), ('wil', 'reach')],
#  [('new', 'theory'),
#   ('theory', 'argument'),
#   ('argument', 'win'),
#   ('win', 'situation'),
#   ('situation', 'loses'),
#   ('loses', 'person'),
#   ('person', 'dont'),
#   ('dont', 'argue'),
#   ('argue', 'ur'),
#   ('ur', 'friend'),
#   ('friend', 'kick'),
#   ('kick', 'amp'),
#   ('amp', 'say'),
#   ('say', 'im'),
#   ('im', 'always'),
#   ('always', 'correct')],
#  [('u', '447801259231'),
#   ('447801259231', 'secret'),
#   ('secret', 'admirer'),
#   ('admirer', 'lookingmake'),
#   ('lookingmake', 'contact'),
#   ('contact', 'ufind'),
#   ('ufind', 'rreveal'),
#   ('rreveal', 'think'),
#   ('think', 'ur'),
#   ('ur', 'specialcall'),
#   ('specialcall', '09058094597')],
#  [('tomarrow', 'final'),
#   ('final', 'hearing'),
#   ('hearing', 'laptop'),
#   ('laptop', 'case'),
#   ('case', 'cant')],
#  [('pleassssssseeeeee', 'telavent'),
#   ('telavent', 'done'),
#   ('done', 'sportsx')],
#  [('okay', 'shining'),
#   ('shining', 'wa'),
#   ('wa', 'meant'),
#   ('meant', 'signing'),
#   ('signing', 'sound'),
#   ('sound', 'better')],
#  [('although', 'tolddat'),
#   ('tolddat', 'im'),
#   ('im', 'baig'),
#   ('baig', 'face'),
#   ('face', 'watch'),
#   ('watch', 'really'),
#   ('really', 'likewatchgave'),
#   ('likewatchgave', 'co'),
#   ('co', 'frthanxeverything'),
#   ('frthanxeverything', 'dat'),
#   ('dat', 'uve'),
#   ('uve', 'done'),
#   ('done', 'today'),
#   ('today', 'im'),
#   ('im', 'touched')],
#  [('u', 'dont'),
#   ('dont', 'remember'),
#   ('remember', 'old'),
#   ('old', 'commercial')],
#  [('late', 'said'),
#   ('said', 'website'),
#   ('website', 'didnt'),
#   ('didnt', 'dont'),
#   ('dont', 'slipper')],
#  [('asked', 'call'), ('call', 'ok')],
#  [('kallis', 'wont'), ('wont', 'bat'), ('bat', '2nd'), ('2nd', 'inning')],
#  [('didnt', 'work'),
#   ('work', 'oh'),
#   ('oh', 'ok'),
#   ('ok', 'goodnight'),
#   ('goodnight', 'ill'),
#   ('ill', 'fix'),
#   ('fix', 'ready'),
#   ('ready', 'time'),
#   ('time', 'wake'),
#   ('wake', 'dearly'),
#   ('dearly', 'missed'),
#   ('missed', 'good'),
#   ('good', 'night'),
#   ('night', 'sleep')],
#  [('congratulation', 'ur'),
#   ('ur', 'awarded'),
#   ('awarded', '500'),
#   ('500', 'cd'),
#   ('cd', 'voucher'),
#   ('voucher', '125gift'),
#   ('125gift', 'guaranteed'),
#   ('guaranteed', 'free'),
#   ('free', 'entry100'),
#   ('entry100', 'wkly'),
#   ('wkly', 'draw'),
#   ('draw', 'txt'),
#   ('txt', 'music'),
#   ('music', '87066'),
#   ('87066', 'tncs'),
#   ('tncs', 'wwwldewcom1win150ppmx3age16')],
#  [('ranjith', 'cal'),
#   ('cal', 'drpd'),
#   ('drpd', 'deeraj'),
#   ('deeraj', 'deepak'),
#   ('deepak', '5min'),
#   ('5min', 'hold')],
#  [('wen', 'ur'),
#   ('ur', 'lovable'),
#   ('lovable', 'bcums'),
#   ('bcums', 'angry'),
#   ('angry', 'widdnt'),
#   ('widdnt', 'take'),
#   ('take', 'seriously'),
#   ('seriously', 'coz'),
#   ('coz', 'angry'),
#   ('angry', 'childishtrue'),
#   ('childishtrue', 'way'),
#   ('way', 'showing'),
#   ('showing', 'deep'),
#   ('deep', 'affection'),
#   ('affection', 'careluv'),
#   ('careluv', 'kettoda'),
#   ('kettoda', 'manda'),
#   ('manda', 'nice'),
#   ('nice', 'day'),
#   ('day', 'da')],
#  [],
#  [('ups', '3days'),
#   ('3days', 'also'),
#   ('also', 'shipping'),
#   ('shipping', 'company'),
#   ('company', 'take'),
#   ('take', '2wks'),
#   ('2wks', 'way'),
#   ('way', 'usps'),
#   ('usps', 'take'),
#   ('take', 'week'),
#   ('week', 'get'),
#   ('get', 'lag'),
#   ('lag', 'may'),
#   ('may', 'bribe'),
#   ('bribe', 'nipost'),
#   ('nipost', 'get'),
#   ('get', 'stuff')],
#  [('im', 'back'),
#   ('back', 'lemme'),
#   ('lemme', 'know'),
#   ('know', 'youre'),
#   ('youre', 'ready')],
#  [('dont', 'necessarily'),
#   ('necessarily', 'expect'),
#   ('expect', 'done'),
#   ('done', 'get'),
#   ('get', 'back'),
#   ('back', 'though'),
#   ('though', 'im'),
#   ('im', 'headin')],
#  [('mmm', 'yummy'),
#   ('yummy', 'babe'),
#   ('babe', 'nice'),
#   ('nice', 'jolt'),
#   ('jolt', 'suzy')],
#  [('lover', 'need')],
#  [('tried', 'contact'),
#   ('contact', 'reply'),
#   ('reply', 'offer'),
#   ('offer', 'video'),
#   ('video', 'handset'),
#   ('handset', '750'),
#   ('750', 'anytime'),
#   ('anytime', 'network'),
#   ('network', 'min'),
#   ('min', 'unlimited'),
#   ('unlimited', 'text'),
#   ('text', 'camcorder'),
#   ('camcorder', 'reply'),
#   ('reply', 'call'),
#   ('call', '08000930705')],
#  [('ium', 'parked'),
#   ('parked', 'next'),
#   ('next', 'mini'),
#   ('mini', 'coming'),
#   ('coming', 'today'),
#   ('today', 'think')],
#  [],
#  [('anyway', 'im'),
#   ('im', 'going'),
#   ('going', 'shopping'),
#   ('shopping', 'co'),
#   ('co', 'si'),
#   ('si', 'done'),
#   ('done', 'yet'),
#   ('yet', 'dun'),
#   ('dun', 'disturbliao')],
#  [('luton', '0125698789'),
#   ('0125698789', 'ring'),
#   ('ring', 'ur'),
#   ('ur', 'around'),
#   ('around', 'h')],
#  [('hey', 'really'),
#   ('really', 'horny'),
#   ('horny', 'want'),
#   ('want', 'chat'),
#   ('chat', 'see'),
#   ('see', 'naked'),
#   ('naked', 'text'),
#   ('text', 'hot'),
#   ('hot', '69698'),
#   ('69698', 'text'),
#   ('text', 'charged'),
#   ('charged', '150pm'),
#   ('150pm', 'unsubscribe'),
#   ('unsubscribe', 'text'),
#   ('text', 'stop'),
#   ('stop', '69698')],
#  [('dint', 'come'), ('come', 'u')],
#  [('wana', 'plan'), ('plan', 'trip'), ('trip', 'sometme')],
#  [('sure', 'yet'),
#   ('yet', 'still'),
#   ('still', 'trying'),
#   ('trying', 'get'),
#   ('get', 'hold')],
#  [('ur', 'ringtone'),
#   ('ringtone', 'service'),
#   ('service', 'ha'),
#   ('ha', 'changed'),
#   ('changed', '25'),
#   ('25', 'free'),
#   ('free', 'credit'),
#   ('credit', 'go'),
#   ('go', 'club4mobilescom'),
#   ('club4mobilescom', 'choose'),
#   ('choose', 'content'),
#   ('content', 'stop'),
#   ('stop', 'txt'),
#   ('txt', 'club'),
#   ('club', 'stop'),
#   ('stop', '87070'),
#   ('87070', '150pwk'),
#   ('150pwk', 'club4'),
#   ('club4', 'po'),
#   ('po', 'box1146'),
#   ('box1146', 'mk45'),
#   ('mk45', '2wt')],
#  [('evo', 'download'), ('download', 'flash'), ('flash', 'jealous')],
#  [('ringtone', 'club'),
#   ('club', 'get'),
#   ('get', 'uk'),
#   ('uk', 'single'),
#   ('single', 'chart'),
#   ('chart', 'mobile'),
#   ('mobile', 'week'),
#   ('week', 'choose'),
#   ('choose', 'top'),
#   ('top', 'quality'),
#   ('quality', 'ringtone'),
#   ('ringtone', 'message'),
#   ('message', 'free'),
#   ('free', 'charge')],
#  [('come', 'mu'),
#   ('mu', 'sorting'),
#   ('sorting', 'narcotic'),
#   ('narcotic', 'situation')],
#  [('night', 'ha'),
#   ('ha', 'ended'),
#   ('ended', 'another'),
#   ('another', 'day'),
# ...
#   ('libertine', 'stroke'),
#   ('stroke', 'win'),
#   ('win', 'nookii'),
#   ('nookii', 'game'),
#   ('game', 'flirt'),
#   ('flirt', 'click'),
#   ('click', 'themob'),
#   ('themob', 'wap'),
#   ('wap', 'bookmark'),
#   ('bookmark', 'text'),
#   ('text', 'wap'),
#   ('wap', '82468')],
#  [('ill', 'give'),
#   ('give', 'plus'),
#   ('plus', 'said'),
#   ('said', 'grinule'),
#   ('grinule', 'greet'),
#   ('greet', 'whenever'),
#   ('whenever', 'speak')],
#  [('white', 'fudge'), ('fudge', 'oreo'), ('oreo', 'store')],
#  [('january', 'male'),
#   ('male', 'sale'),
#   ('sale', 'hot'),
#   ('hot', 'gay'),
#   ('gay', 'chat'),
#   ('chat', 'cheaper'),
#   ('cheaper', 'call'),
#   ('call', '08709222922'),
#   ('08709222922', 'national'),
#   ('national', 'rate'),
#   ('rate', '15pmin'),
#   ('15pmin', 'cheap'),
#   ('cheap', '78pmin'),
#   ('78pmin', 'peak'),
#   ('peak', 'stop'),
#   ('stop', 'text'),
#   ('text', 'call'),
#   ('call', '08712460324'),
#   ('08712460324', '10pmin')],
#  [('love', 'come'),
#   ('come', 'took'),
#   ('took', 'long'),
#   ('long', 'leave'),
#   ('leave', 'zahers'),
#   ('zahers', 'got'),
#   ('got', 'word'),
#   ('word', 'ym'),
#   ('ym', 'wa'),
#   ('wa', 'happy'),
#   ('happy', 'see'),
#   ('see', 'wa'),
#   ('wa', 'sad'),
#   ('sad', 'left'),
#   ('left', 'miss')],
#  [('sorry', 'hurt')],
#  [('cant', 'feel'),
#   ('feel', 'nauseous'),
#   ('nauseous', 'im'),
#   ('im', 'pissed'),
#   ('pissed', 'didnt'),
#   ('didnt', 'eat'),
#   ('eat', 'sweet'),
#   ('sweet', 'week'),
#   ('week', 'cause'),
#   ('cause', 'today'),
#   ('today', 'wa'),
#   ('wa', 'planning'),
#   ('planning', 'pig'),
#   ('pig', 'wa'),
#   ('wa', 'dieting'),
#   ('dieting', 'week'),
#   ('week', 'im'),
#   ('im', 'hungry')],
#  [('ok', 'lor'),
#   ('lor', 'early'),
#   ('early', 'still'),
#   ('still', 'project'),
#   ('project', 'meeting')],
#  [('call', 'da'), ('da', 'waiting'), ('waiting', 'call')],
#  [('could', 'ask'),
#   ('ask', 'carlos'),
#   ('carlos', 'could'),
#   ('could', 'get'),
#   ('get', 'anybody'),
#   ('anybody', 'else'),
#   ('else', 'chip')],
#  [('wa', 'actually'),
#   ('actually', 'send'),
#   ('send', 'reminder'),
#   ('reminder', 'today'),
#   ('today', 'wonderful'),
#   ('wonderful', 'weekend')],
#  [('people', 'see'),
#   ('see', 'msg'),
#   ('msg', 'think'),
#   ('think', 'iam'),
#   ('iam', 'addicted'),
#   ('addicted', 'msging'),
#   ('msging', 'wrong'),
#   ('wrong', 'bcoz'),
#   ('bcoz', 'dont'),
#   ('dont', 'know'),
#   ('know', 'iam'),
#   ('iam', 'addicted'),
#   ('addicted', 'sweet'),
#   ('sweet', 'friend'),
#   ('friend', 'bslvyl')],
#  [('hey', 'gave'),
#   ('gave', 'photo'),
#   ('photo', 'registered'),
#   ('registered', 'driving'),
#   ('driving', 'ah'),
#   ('ah', 'tmr'),
#   ('tmr', 'wanna'),
#   ('wanna', 'meet'),
#   ('meet', 'yck')],
#  [('dont', 'talk'), ('talk', 'ever'), ('ever', 'ok'), ('ok', 'word')],
#  [('u', 'wana'), ('wana', 'see')],
#  [('way', 'school'),
#   ('school', 'pls'),
#   ('pls', 'send'),
#   ('send', 'ashleys'),
#   ('ashleys', 'number')],
#  [('shall', 'fine'), ('fine', 'avalarr'), ('avalarr', 'hollalater')],
#  [('went', 'attend'),
#   ('attend', 'another'),
#   ('another', 'two'),
#   ('two', 'round'),
#   ('round', 'todaybut'),
#   ('todaybut', 'still'),
#   ('still', 'didt'),
#   ('didt', 'reach'),
#   ('reach', 'home')],
#  [('actually', 'deleted'),
#   ('deleted', 'old'),
#   ('old', 'websitenow'),
#   ('websitenow', 'blogging'),
#   ('blogging', 'magicalsongsblogspotcom')],
#  [('k', 'wait'),
#   ('wait', 'chikkuil'),
#   ('chikkuil', 'send'),
#   ('send', 'aftr'),
#   ('aftr', 'ltgt'),
#   ('ltgt', 'min')],
#  [('im', 'diet'),
#   ('diet', 'atemany'),
#   ('atemany', 'slice'),
#   ('slice', 'pizza'),
#   ('pizza', 'yesterday'),
#   ('yesterday', 'ugh'),
#   ('ugh', 'im'),
#   ('im', 'always'),
#   ('always', 'diet')],
#  [('ki', 'give'), ('give', 'kvb'), ('kvb', 'acc'), ('acc', 'detail')],
#  [('oh', 'come'), ('come', 'ah')],
#  [('moneylucky', 'winnerclaim'),
#   ('winnerclaim', 'prize'),
#   ('prize', 'text'),
#   ('text', 'money88600'),
#   ('money88600', 'a1million'),
#   ('a1million', 'give'),
#   ('give', 'away'),
#   ('away', 'ppt150x3normal'),
#   ('ppt150x3normal', 'text'),
#   ('text', 'rate'),
#   ('rate', 'box403'),
#   ('box403', 'w1t1jy')],
#  [('im', 'really'),
#   ('really', 'sorry'),
#   ('sorry', 'wontablefridayhopefind'),
#   ('wontablefridayhopefind', 'alternativehope'),
#   ('alternativehope', 'yr'),
#   ('yr', 'term'),
#   ('term', 'going'),
#   ('going', 'ok')],
#  [('congratulation', 'ore'),
#   ('ore', 'mo'),
#   ('mo', 'owo'),
#   ('owo', 'wa'),
#   ('wa', 'enjoy'),
#   ('enjoy', 'wish'),
#   ('wish', 'many'),
#   ('many', 'happy'),
#   ('happy', 'moment'),
#   ('moment', 'fro'),
#   ('fro', 'wherever'),
#   ('wherever', 'go')],
#  [('samus', 'shoulder'), ('shoulder', 'yet')],
#  [('time', 'think'),
#   ('think', 'youll'),
#   ('youll', 'need'),
#   ('need', 'know'),
#   ('know', 'near'),
#   ('near', 'campus')],
#  [('dear', 'matthew'),
#   ('matthew', 'please'),
#   ('please', 'call'),
#   ('call', '09063440451'),
#   ('09063440451', 'landline'),
#   ('landline', 'complimentary'),
#   ('complimentary', '4lux'),
#   ('4lux', 'tenerife'),
#   ('tenerife', 'holiday'),
#   ('holiday', 'a1000'),
#   ('a1000', 'cash'),
#   ('cash', 'await'),
#   ('await', 'collection'),
#   ('collection', 'ppm150'),
#   ('ppm150', 'sae'),
#   ('sae', 'tc'),
#   ('tc', 'box334'),
#   ('box334', 'sk38xh')],
#  [('dun', 'wear'), ('wear', 'jean'), ('jean', 'lor')],
#  [('since', 'side'), ('side', 'fever'), ('fever', 'vomitin')],
#  [('kkare', 'college')],
#  [('urgent', 'call'),
#   ('call', '09061749602'),
#   ('09061749602', 'landline'),
#   ('landline', 'complimentarytenerife'),
#   ('complimentarytenerife', 'holiday'),
#   ('holiday', 'a10000'),
#   ('a10000', 'cash'),
#   ('cash', 'await'),
#   ('await', 'collection'),
#   ('collection', 'sae'),
#   ('sae', 'tc'),
#   ('tc', 'box'),
#   ('box', '528'),
#   ('528', 'hp20'),
#   ('hp20', '1yf'),
#   ('1yf', '150ppm'),
#   ('150ppm', '18')],
#  [('better', 'made'),
#   ('made', 'friday'),
#   ('friday', 'stuffed'),
#   ('stuffed', 'like'),
#   ('like', 'pig'),
#   ('pig', 'yesterday'),
#   ('yesterday', 'feel'),
#   ('feel', 'bleh'),
#   ('bleh', 'least'),
#   ('least', 'writhing'),
#   ('writhing', 'pain'),
#   ('pain', 'kind'),
#   ('kind', 'bleh')],
#  [('sell', 'well'),
#   ('well', 'ton'),
#   ('ton', 'coin'),
#   ('coin', 'sell'),
#   ('sell', 'coin'),
#   ('coin', 'someone'),
#   ('someone', 'thru'),
#   ('thru', 'paypal'),
#   ('paypal', 'voila'),
#   ('voila', 'money'),
#   ('money', 'back'),
#   ('back', 'life'),
#   ('life', 'pocket')],
#  [('theyre', 'lot'),
#   ('lot', 'place'),
#   ('place', 'hospital'),
#   ('hospital', 'medical'),
#   ('medical', 'place'),
#   ('place', 'safe')],
#  [('getting', 'touch'),
#   ('touch', 'folk'),
#   ('folk', 'waiting'),
#   ('waiting', 'company'),
#   ('company', 'txt'),
#   ('txt', 'back'),
#   ('back', 'name'),
#   ('name', 'age'),
#   ('age', 'opt'),
#   ('opt', 'enjoy'),
#   ('enjoy', 'community'),
#   ('community', '150psms')],
#  [('also', 'ive'),
#   ('ive', 'sorta'),
#   ('sorta', 'blown'),
#   ('blown', 'couple'),
#   ('couple', 'time'),
#   ('time', 'recently'),
#   ('recently', 'id'),
#   ('id', 'rather'),
#   ('rather', 'text'),
#   ('text', 'blue'),
#   ('blue', 'looking'),
#   ('looking', 'weed')],
#  [('sent', 'score'),
#   ('score', 'sophas'),
#   ('sophas', 'secondary'),
#   ('secondary', 'application'),
#   ('application', 'school'),
#   ('school', 'think'),
#   ('think', 'thinking'),
#   ('thinking', 'applying'),
#   ('applying', 'research'),
#   ('research', 'cost'),
#   ('cost', 'also'),
#   ('also', 'contact'),
#   ('contact', 'joke'),
#   ('joke', 'ogunrinde'),
#   ('ogunrinde', 'school'),
#   ('school', 'one'),
#   ('one', 'le'),
#   ('le', 'expensive'),
#   ('expensive', 'one')],
#  [('cant', 'wait'), ('wait', 'see'), ('see', 'photo'), ('photo', 'useful')],
#  [('ur', 'cashbalance'),
#   ('cashbalance', 'currently'),
#   ('currently', '500'),
#   ('500', 'pound'),
#   ('pound', 'maximize'),
#   ('maximize', 'ur'),
#   ('ur', 'cashin'),
#   ('cashin', 'send'),
#   ('send', 'go'),
#   ('go', '86688'),
#   ('86688', '150pmsg'),
#   ('150pmsg', 'cc'),
#   ('cc', '08718720201'),
#   ('08718720201', 'po'),
#   ('po', 'box'),
#   ('box', '11414'),
#   ('11414', 'tcrw1')],
#  [('hey', 'booked'),
#   ('booked', 'kb'),
#   ('kb', 'sat'),
#   ('sat', 'already'),
#   ('already', 'lesson'),
#   ('lesson', 'going'),
#   ('going', 'ah'),
#   ('ah', 'keep'),
#   ('keep', 'sat'),
#   ('sat', 'night'),
#   ('night', 'free'),
#   ('free', 'need'),
#   ('need', 'meet'),
#   ('meet', 'confirm'),
#   ('confirm', 'lodging')],
#  [('chk', 'ur'), ('ur', 'belovd'), ('belovd', 'dict')],
#  [('time', 'want'), ('want', 'come')],
#  [('awesome', 'lemme'),
#   ('lemme', 'know'),
#   ('know', 'whenever'),
#   ('whenever', 'youre'),
#   ('youre', 'around')],
#  [('shbok', 'lor'), ('lor', 'thanx')],
#  [('beautiful', 'truth'),
#   ('truth', 'gravity'),
#   ('gravity', 'read'),
#   ('read', 'carefully'),
#   ('carefully', 'heart'),
#   ('heart', 'feel'),
#   ('feel', 'light'),
#   ('light', 'someone'),
#   ('someone', 'feel'),
#   ('feel', 'heavy'),
#   ('heavy', 'someone'),
#   ('someone', 'leaf'),
#   ('leaf', 'good'),
#   ('good', 'night')],
#  [('also', 'remember'),
#   ('remember', 'get'),
#   ('get', 'dobbys'),
#   ('dobbys', 'bowl'),
#   ('bowl', 'car')],
#  [('filthy', 'story'), ('story', 'girl'), ('girl', 'waiting')],
#  [('sorryur', 'msg'),
#   ('msg', 'yar'),
#   ('yar', 'lor'),
#   ('lor', 'poor'),
#   ('poor', 'thingone'),
#   ('thingone', 'night'),
#   ('night', 'tmr'),
#   ('tmr', 'ull'),
#   ('ull', 'brand'),
#   ('brand', 'new'),
#   ('new', 'roomsleep')],
#  [('love', 'isnt'),
#   ('isnt', 'decision'),
#   ('decision', 'feeling'),
#   ('feeling', 'could'),
#   ('could', 'decide'),
#   ('decide', 'love'),
#   ('love', 'life'),
#   ('life', 'would'),
#   ('would', 'much'),
#   ('much', 'simpler'),
#   ('simpler', 'le'),
#   ('le', 'magical')],
#  [('welp', 'apparently'), ('apparently', 'retired')],
#  [('sort', 'code'),
#   ('code', 'acc'),
#   ('acc', 'bank'),
#   ('bank', 'natwest'),
#   ('natwest', 'reply'),
#   ('reply', 'confirm'),
#   ('confirm', 'ive'),
#   ('ive', 'sent'),
#   ('sent', 'right'),
#   ('right', 'person')],
#  [('u', 'surecant'), ('surecant', 'take'), ('take', 'sick'), ('sick', 'time')],
#  [('urgent', 'trying'),
#   ('trying', 'contacttoday'),
#   ('contacttoday', 'draw'),
#   ('draw', 'show'),
#   ('show', 'a800'),
#   ('a800', 'prize'),
#   ('prize', 'guaranteed'),
#   ('guaranteed', 'call'),
#   ('call', '09050001808'),
#   ('09050001808', 'land'),
#   ('land', 'line'),
#   ('line', 'claim'),
#   ('claim', 'm95'),
#   ('m95', 'valid12hrs')],
#  [('watching', 'cartoon'),
#   ('cartoon', 'listening'),
#   ('listening', 'music'),
#   ('music', 'amp'),
#   ('amp', 'eve'),
#   ('eve', 'go'),
#   ('go', 'temple'),
#   ('temple', 'amp'),
#   ('amp', 'church'),
#   ('church', 'u')],
#  [('yo', 'chad'),
#   ('chad', 'gymnastics'),
#   ('gymnastics', 'class'),
#   ('class', 'wanna'),
#   ('wanna', 'take'),
#   ('take', 'site'),
#   ('site', 'say'),
#   ('say', 'christian'),
#   ('christian', 'class'),
#   ('class', 'full')],
#  [('much', 'buzy')],
#  [('better', 'still'),
#   ('still', 'catch'),
#   ('catch', 'let'),
#   ('let', 'ask'),
#   ('ask', 'sell'),
#   ('sell', 'ltgt')],
#  [('sure', 'night'),
#   ('night', 'menu'),
#   ('menu', 'know'),
#   ('know', 'noon'),
#   ('noon', 'menu')],
#  [('u', 'want'),
#   ('want', 'come'),
#   ('come', 'backa'),
#   ('backa', 'beautiful'),
#   ('beautiful', 'necklace'),
#   ('necklace', 'token'),
#   ('token', 'heart'),
#   ('heart', 'youthats'),
#   ('youthats', 'give'),
#   ('give', 'wife'),
#   ('wife', 'likingbe'),
#   ('likingbe', 'seeno'),
#   ('seeno', 'one'),
#   ('one', 'give'),
#   ('give', 'thatdont'),
#   ('thatdont', 'call'),
#   ('call', 'mei'),
#   ('mei', 'wait'),
#   ('wait', 'till'),
#   ('till', 'come')],
#  [('willing', 'go'), ('go', 'aptitude'), ('aptitude', 'class')],
#  [('wont215', 'tryingsort'), ('tryingsort', 'house'), ('house', 'ok')],
#  [('yar', 'lor'),
#   ('lor', 'wangohorse'),
#   ('wangohorse', 'racing'),
#   ('racing', 'today'),
#   ('today', 'mah'),
#   ('mah', 'eat'),
#   ('eat', 'earlier'),
#   ('earlier', 'lor'),
#   ('lor', 'ate'),
#   ('ate', 'chicken'),
#   ('chicken', 'rice'),
#   ('rice', 'u')],
#  [('haha', 'awesome'), ('awesome', 'omw'), ('omw', 'back')],
#  [('yup', 'thkshop'), ('thkshop', 'close'), ('close', 'lor')],
#  [('account', 'number')],
#  [('ehsend', 'wrongly'), ('wrongly', 'lar')],
#  [('hey', 'ad'),
#   ('ad', 'crap'),
#   ('crap', 'nite'),
#   ('nite', 'wa'),
#   ('wa', 'borin'),
#   ('borin', 'without'),
#   ('without', 'yaboggyboring'),
#   ('yaboggyboring', 'biatch'),
#   ('biatch', 'thanxwait'),
#   ('thanxwait', 'til'),
#   ('til', 'nxt'),
#   ('nxt', 'time'),
#   ('time', 'il'),
#   ('il', 'ave'),
#   ('ave', 'ya')],
#  [('ok', 'shall'), ('shall', 'talk')],
#  [('dont', 'hesitate'),
#   ('hesitate', 'know'),
#   ('know', 'second'),
#   ('second', 'time'),
#   ('time', 'ha'),
#   ('ha', 'weakness'),
#   ('weakness', 'like'),
#   ('like', 'keep'),
#   ('keep', 'notebook'),
#   ('notebook', 'eat'),
#   ('eat', 'day'),
#   ('day', 'anything'),
#   ('anything', 'changed'),
#   ('changed', 'day'),
#   ('day', 'sure'),
#   ('sure', 'nothing')],
#  [('hey', 'pay'), ('pay', 'salary'), ('salary', 'de'), ('de', 'ltgt')],
#  [('another', 'month'),
#   ('month', 'need'),
#   ('need', 'chocolate'),
#   ('chocolate', 'weed'),
#   ('weed', 'alcohol')],
#  [('started', 'searching'),
#   ('searching', 'get'),
#   ('get', 'job'),
#   ('job', 'dayshe'),
#   ('dayshe', 'great'),
#   ('great', 'potential'),
#   ('potential', 'talent')],
#  [('reckon', 'need'),
#   ('need', 'town'),
#   ('town', 'eightish'),
#   ('eightish', 'walk'),
#   ('walk', 'carpark')],
#  [('congratsmobile', '3g'),
#   ('3g', 'videophonescall'),
#   ('videophonescall', '09063458130'),
#   ('09063458130', 'videochat'),
#   ('videochat', 'wid'),
#   ('wid', 'mate'),
#   ('mate', 'play'),
#   ('play', 'java'),
#   ('java', 'game'),
#   ('game', 'dload'),
#   ('dload', 'polyph'),
#   ('polyph', 'music'),
#   ('music', 'noline'),
#   ('noline', 'rentl')],
#  [('look', 'fuckin'), ('fuckin', 'time'), ('time', 'fuck'), ('fuck', 'think')],
#  [('yo', 'guess'), ('guess', 'dropped')],
#  [('carlos', 'say'),
#   ('say', 'hell'),
#   ('hell', 'mu'),
#   ('mu', 'ltgt'),
#   ('ltgt', 'minute')],
#  [('im', 'office'), ('office', 'call'), ('call', 'ltgt'), ('ltgt', 'min')],
#  [('geeee', 'miss'),
#   ('miss', 'already'),
#   ('already', 'know'),
#   ('know', 'think'),
#   ('think', 'fuck'),
#   ('fuck', 'cant'),
#   ('cant', 'wait'),
#   ('wait', 'till'),
#   ('till', 'next'),
#   ('next', 'year'),
#   ('year', 'together'),
#   ('together', 'loving'),
#   ('loving', 'kiss')],
#  [('yun', 'ahthe'),
#   ('ahthe', 'ubi'),
#   ('ubi', 'one'),
#   ('one', 'say'),
#   ('say', 'wan'),
#   ('wan', 'call'),
#   ('call', 'tomorrowcall'),
#   ('tomorrowcall', '67441233'),
#   ('67441233', 'look'),
#   ('look', 'ireneere'),
#   ('ireneere', 'got'),
#   ('got', 'bus822656166382'),
#   ('bus822656166382', 'ubi'),
#   ('ubi', 'cresubi'),
#   ('cresubi', 'tech'),
#   ('tech', 'park6ph'),
#   ('park6ph', '1st'),
#   ('1st', '5wkg'),
#   ('5wkg', 'daysin')],
#  [('ugh', 'gotta'),
#   ('gotta', 'drive'),
#   ('drive', 'back'),
#   ('back', 'sd'),
#   ('sd', 'la'),
#   ('la', 'butt'),
#   ('butt', 'sore')],
#  [('26th', 'july')],
#  [('hi', 'im'),
#   ('im', 'relaxing'),
#   ('relaxing', 'time'),
#   ('time', 'ever'),
#   ('ever', 'get'),
#   ('get', '7am'),
#   ('7am', 'every'),
#   ('every', 'day'),
#   ('day', 'wa'),
#   ('wa', 'party'),
#   ('party', 'good'),
#   ('good', 'night'),
#   ('night', 'get'),
#   ('get', 'home'),
#   ('home', 'tomorrow'),
#   ('tomorrow', '5ish')],
#  [('ii', 'wan'),
#   ('wan', 'come'),
#   ('come', 'come'),
#   ('come', 'lor'),
#   ('lor', 'dinstripe'),
#   ('dinstripe', 'skirt')],
#  [('xmas', 'story'),
#   ('story', 'peace'),
#   ('peace', 'xmas'),
#   ('xmas', 'msg'),
#   ('msg', 'love'),
#   ('love', 'xmas'),
#   ('xmas', 'miracle'),
#   ('miracle', 'jesus'),
#   ('jesus', 'hav'),
#   ('hav', 'blessed'),
#   ('blessed', 'month'),
#   ('month', 'ahead'),
#   ('ahead', 'amp'),
#   ('amp', 'wishmerry'),
#   ('wishmerry', 'xmas')],
#  [('cant', 'dont'), ('dont', 'number')],
#  [('changeone', 'next'), ('next', 'escalator')],
#  [('yetunde', 'im'),
#   ('im', 'class'),
#   ('class', 'run'),
#   ('run', 'water'),
#   ('water', 'make'),
#   ('make', 'ok'),
#   ('ok', 'pls')],
#  [('lot', 'ha'),
#   ('ha', 'happened'),
#   ('happened', 'feel'),
#   ('feel', 'quiet'),
#   ('quiet', 'beth'),
#   ('beth', 'aunt'),
#   ('aunt', 'charlie'),
#   ('charlie', 'working'),
#   ('working', 'lot'),
#   ('lot', 'helen'),
#   ('helen', 'mo')],
#  [('waitbus', 'stop'),
#   ('stop', 'aft'),
#   ('aft', 'ur'),
#   ('ur', 'lect'),
#   ('lect', 'lar'),
#   ('lar', 'dungo'),
#   ('dungo', 'get'),
#   ('get', 'car'),
#   ('car', 'come'),
#   ('come', 'backpick')],
#  [('aight', 'thanks'), ('thanks', 'comin')],
#  [('nobut', 'heard'), ('heard', 'abt'), ('abt', 'tat')],
#  ...]

# %%
ham_bigrams = pd.Series(list(nltk.ngrams(ham_words.split(), 2))).value_counts().head(20)
spam_bigrams = pd.Series(list(nltk.ngrams(spam_words.split(), 2))).value_counts().head(20)

# %%
spam_bigrams
# Out:
# (please, call)          43
# (customer, service)     27
# (guaranteed, call)      23
# (po, box)               23
# (prize, guaranteed)     22
# (a1000, cash)           20
# (send, stop)            19
# (every, week)           19
# (land, line)            18
# (await, collection)     18
# (urgent, mobile)        18
# (valid, 12hrs)          17
# (sae, tc)               16
# (account, statement)    16
# (claim, call)           16
# (reply, call)           15
# (selected, receive)     15
# (call, customer)        15
# (call, 08000930705)     15
# (identifier, code)      15
# dtype: int64

# %% [markdown]
# <a id='Bi-Grams_Overlap'></a>
# # Bi-Grams_Overlap

# %%
plt.subplot(1,2,1)
ham_bigrams.plot.barh(color='pink', width=.9, figsize=(10,10), alpha=.8)
plt.title("20 most frequent ham bigrams")
plt.ylabel("Bigram")
plt.xlabel("Frequency")
plt.subplot(1,2,2)
spam_bigrams.plot.barh(color='blue', width=.9, figsize=(10,10), alpha=.3)
plt.title("20 most frequent spam bigrams")
plt.ylabel("Bigram")
plt.xlabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Takeaways**
# - spam = please call vs. ham = call later
# - spam are more formal and generic, ham are personal
# - don't see overlap

# %% [markdown]
# We can apply the same transformation to our ham data set in order to find out which bigrams are the most frequently occuring.

# %% [markdown]
# We can use these bigrams to make a word cloud as well, with a little more effort.

# %%
# We can supply our own values to be used to determine how big the words (or
# phrases) should be through the `generate_from_frequencies` method. The
# supplied values must be in the form of a dictionary where the keys are the
# words (phrases), and the values are numbers that correspond to the sizes.
#
# We'll convert our series to a dictionary, and convert the tuples that make up
# the index into a single string that holds each phrase.

# for ham_bigrams
data = {k[0] + ' ' + k[1]: v for k, v in ham_bigrams.to_dict().items()}
img = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(data)
plt.figure(figsize=(8, 4))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
# for spam_bigrams
data = {k[0] + ' ' + k[1]: v for k, v in spam_bigrams.to_dict().items()}
img = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(data)
plt.figure(figsize=(8, 4))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %% [markdown]
# # Exercises
#
# Do your work for this exercise in a file named `explore`.
#
# 1. Spam Data
#
#     1. Load the spam data set.
#     1. Create and explore bigrams for the spam data. Visualize them with a word
#        cloud. How do they compare with the ham bigrams?
#     1. Is there any overlap in the bigrams for the spam data and the ham data?
#     1. Create and explore with trigrams (i.e. a n-gram with an n of 3) for both the spam and ham data.
#     1. BONUS: plot the document length information of spam vs. ham. Does there appear to be a difference?
#
#
# 1. Explore the blog articles using the techniques discussed in the exploration
#    lesson.
#
# 1. Explore the news articles using the techniques discussed in the exploration
#    lesson. Use the `category` variable when exploring.

# %% [markdown]
# 1.A. = see [setup](#Setup)

# %% [markdown]
# 1.B. = see [Bi-Grams](#Bi-Grams)

# %% [markdown]
# 1.C. = see [Bi-Grams_Overlap](#Bi-Grams_Overlap)

# %%
# 1.D. Create and explore with trigrams (i.e. a n-gram with an n of 3) for both the spam and ham data.

# %% [markdown]
# # Feature Extraction
#
# 1. Word count: how many words appear in each document
# 2. Term Frequency (TF): How often a word appears in a document.
# 3. Inverse Document Frequency (IDF): How much information a word provides, based on how commonly a word appears across multiple documents. The more frequently a word appears, the lower the IDF for that word will be. $$
# \mbox{idf}(\mbox{word})
# =
# \log\left(\frac{\mbox{# of documents}}{\mbox{# of documents containing the word}}\right)
# $$
#
# 4. Term Frequency - Inverse Document Frequency (TF-IDF): The multiplication of the two measures above. A word that has a high frequency in a document will have a high TF. If it appears in many other documents, than the information the word provides, or uniqueness of that word, is lowered. This is done mathematically by multiplying by the IDF, which will approach 0 and the number of documents with the word increases.

# %% [markdown]
# ## Term Frequency
#
# Term frequency describes how frequently a word appears **in a document**. It can be calculated in a number of ways:
#
# - **Raw Count**: The count of the number of occurences of each word **in the document**.
#
# - **Frequency**: The number of times each word appears divided by the total number of words **in the document**.
#
# - **Augmented Frequency**: The frequency of each word divided by the maximum frequency **in the document**. This can help prevent bias towards larger documents.
